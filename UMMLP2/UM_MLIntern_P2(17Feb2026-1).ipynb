# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/UMMLP2/UM_MLIntern_P2(17Feb2026-1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Fraud Detection in Financial Transaction

# %% [markdown]
# ###Import Lib's

# %%
import os
#import zipfile
import zipfile
#import ZipFile

# %%
print(os.getcwd())
# Out:
# /content

# %%
input_path='/content/sample_data/dataset.zip'
output_path='/content/FD_P2'

print("Is zip:", zipfile.is_zipfile(input_path))
# Out:
# Is zip: True

# %%
with zipfile.ZipFile(input_path, 'r') as zf:
     zf.extractall(output_path)
     print('File Extraction Successful')
# Out:
# File Extraction Successful

# %%
import os

def count_files_os(folder_path):
    """Counts the number of files in a given folder using os.listdir."""

    count = 0

    # List all entries in the directory
    for file in os.listdir(folder_path):

        # Construct the full path
        full_path = os.path.join(folder_path, file)

        # Check if the entry is a file (and not a sub-directory or symlink)
        if os.path.isfile(full_path):
            count += 1

    return count

# Example Usage:
# Replace 'your/folder/path' with the actual path to your folder
folder_to_check = '/content/FD_P2/data'

file_count = count_files_os(folder_to_check)
#print(f"Total files count ::'{folder_to_check}': {file_count}")
print(f"Total files count ::: {file_count}")
# Out:
# Total files count ::: 183

# %%
import glob
import os

# Define the directory path
directory_path = '.'  # Current directory

# Pattern to match all files and directories
# '*' matches everything directly in the specified path
pattern = os.path.join(directory_path, '*')

# Use glob.glob() to get the list of files
file_list = glob.glob(pattern)

print("Files in directory:")
for file in file_list:
    print(file)
# Out:
# Files in directory:
# ./sample_data
# ./FD_P2

# %%
directory_path1='/content/FD_P2/data'
pattern1=os.path.join(directory_path1, '*')
ListofFiles=glob.glob(pattern1)

print("Files in directory:")
for file in ListofFiles:
    print(file)
# Out:
# Files in directory:
# /content/FD_P2/data/2018-07-22.pkl
# /content/FD_P2/data/2018-06-15.pkl
# /content/FD_P2/data/2018-07-14.pkl
# /content/FD_P2/data/2018-08-11.pkl
# /content/FD_P2/data/2018-04-14.pkl
# /content/FD_P2/data/2018-09-07.pkl
# /content/FD_P2/data/2018-09-10.pkl
# /content/FD_P2/data/2018-04-18.pkl
# /content/FD_P2/data/2018-07-11.pkl
# /content/FD_P2/data/2018-06-12.pkl
# /content/FD_P2/data/2018-04-03.pkl
# /content/FD_P2/data/2018-07-02.pkl
# /content/FD_P2/data/2018-08-22.pkl
# /content/FD_P2/data/2018-06-24.pkl
# /content/FD_P2/data/2018-08-14.pkl
# /content/FD_P2/data/2018-08-04.pkl
# /content/FD_P2/data/2018-08-30.pkl
# /content/FD_P2/data/2018-04-17.pkl
# /content/FD_P2/data/2018-08-10.pkl
# /content/FD_P2/data/2018-08-26.pkl
# /content/FD_P2/data/2018-07-24.pkl
# /content/FD_P2/data/2018-06-13.pkl
# /content/FD_P2/data/2018-04-02.pkl
# /content/FD_P2/data/2018-05-09.pkl
# /content/FD_P2/data/2018-07-01.pkl
# /content/FD_P2/data/2018-09-18.pkl
# ...

# %% [markdown]
# ###Reading a Pickle a file

# %%
import pandas as pd
df1=pd.read_pickle('/content/FD_P2/data/2018-09-24.pkl')
df1
# Out:
#          TRANSACTION_ID         TX_DATETIME CUSTOMER_ID TERMINAL_ID  \
# 1687440         1687440 2018-09-24 00:00:27        2524        9558
# 1687441         1687441 2018-09-24 00:01:18        1011        7930
# 1687442         1687442 2018-09-24 00:01:39         872        9471
# 1687443         1687443 2018-09-24 00:02:26        3578        8682
# 1687444         1687444 2018-09-24 00:04:01         942        3757
# ...                 ...                 ...         ...         ...
# 1696859         1696859 2018-09-24 23:55:49        2760        6578
# 1696860         1696860 2018-09-24 23:57:14        2611        2338
# 1696861         1696861 2018-09-24 23:57:38        2932         474
# 1696862         1696862 2018-09-24 23:58:00        3610        4147
# 1696863         1696863 2018-09-24 23:59:20         985        7381
#
#          TX_AMOUNT TX_TIME_SECONDS TX_TIME_DAYS  TX_FRAUD  TX_FRAUD_SCENARIO
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9424 entries, 1687440 to 1696863
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   TRANSACTION_ID     9424 non-null   int64
#  1   TX_DATETIME        9424 non-null   datetime64[ns]
#  2   CUSTOMER_ID        9424 non-null   object
#  3   TERMINAL_ID        9424 non-null   object
#  4   TX_AMOUNT          9424 non-null   float64
#  5   TX_TIME_SECONDS    9424 non-null   object
#  6   TX_TIME_DAYS       9424 non-null   object
#  7   TX_FRAUD           9424 non-null   int64
#  8   TX_FRAUD_SCENARIO  9424 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 994.3+ KB

# %%
df1.describe()
# Out:
#        TRANSACTION_ID                    TX_DATETIME    TX_AMOUNT  \
# count    9.424000e+03                           9424  9424.000000
# mean     1.692152e+06  2018-09-24 12:01:02.105369088    53.856161
# min      1.687440e+06            2018-09-24 00:00:27     0.000000
# 25%      1.689796e+06  2018-09-24 08:25:38.750000128    21.095000
# 50%      1.692152e+06            2018-09-24 11:57:44    44.535000
# 75%      1.694507e+06            2018-09-24 15:41:12    76.792500
# max      1.696863e+06            2018-09-24 23:59:20  2374.500000
# std      2.720619e+03                            NaN    48.926282
#
#           TX_FRAUD  TX_FRAUD_SCENARIO
# count  9424.000000        9424.000000
# mean      0.009126           0.020374
# min       0.000000           0.000000
# 25%       0.000000           0.000000
# 50%       0.000000           0.000000
# 75%       0.000000           0.000000
# max       1.000000           3.000000
# std       0.095096           0.217578

# %%
df1.sample(1).T
# Out:
#                                1691609
# TRANSACTION_ID                 1691609
# TX_DATETIME        2018-09-24 11:12:48
# CUSTOMER_ID                       3517
# TERMINAL_ID                       7714
# TX_AMOUNT                        44.47
# TX_TIME_SECONDS               15246768
# TX_TIME_DAYS                       176
# TX_FRAUD                             0
# TX_FRAUD_SCENARIO                    0

# %%
from datetime import datetime

# %%
import copy as cp

df=df1.copy(deep=True)

# Ensure the column is in datetime format (if not already)
df['TX_DATETIME'] = pd.to_datetime(df1['TX_DATETIME'])

# Create a new 'date' column
df['date'] = df['TX_DATETIME'].dt.date

# Create a new 'time' column
df['time'] = df['TX_DATETIME'].dt.time

# Print the updated DataFrame to verify
print(df[['TX_DATETIME', 'date', 'time']])
# Out:
#                 TX_DATETIME        date      time
# 1687440 2018-09-24 00:00:27  2018-09-24  00:00:27
# 1687441 2018-09-24 00:01:18  2018-09-24  00:01:18
# 1687442 2018-09-24 00:01:39  2018-09-24  00:01:39
# 1687443 2018-09-24 00:02:26  2018-09-24  00:02:26
# 1687444 2018-09-24 00:04:01  2018-09-24  00:04:01
# ...                     ...         ...       ...
# 1696859 2018-09-24 23:55:49  2018-09-24  23:55:49
# 1696860 2018-09-24 23:57:14  2018-09-24  23:57:14
# 1696861 2018-09-24 23:57:38  2018-09-24  23:57:38
# 1696862 2018-09-24 23:58:00  2018-09-24  23:58:00
# 1696863 2018-09-24 23:59:20  2018-09-24  23:59:20
#
# [9424 rows x 3 columns]

# %%
print(df.shape)
print()
df1.shape
# Out:
# (9424, 11)
# (9424, 9)

# %%
#TO FORMAT DATETIME COLUMN USING STRFTIME

df2=df1.copy(deep=True)

# Ensure the column is in datetime format
df2['TX_DATETIME'] = pd.to_datetime(df1['TX_DATETIME'])

# Create a new 'date_string' column formatted as YYYY-MM-DD
df2['date_string'] = df2['TX_DATETIME'].dt.strftime('%Y-%m-%d')

# Create a new 'time_string' column formatted as HH:MM:SS
df2['time_string'] = df2['TX_DATETIME'].dt.strftime('%H:%M:%S')

# Print the updated DataFrame to verify
print(df2[['TX_DATETIME', 'date_string', 'time_string']])
print()
print(df2.shape)
print()
# Out:
#                 TX_DATETIME date_string time_string
# 1687440 2018-09-24 00:00:27  2018-09-24    00:00:27
# 1687441 2018-09-24 00:01:18  2018-09-24    00:01:18
# 1687442 2018-09-24 00:01:39  2018-09-24    00:01:39
# 1687443 2018-09-24 00:02:26  2018-09-24    00:02:26
# 1687444 2018-09-24 00:04:01  2018-09-24    00:04:01
# ...                     ...         ...         ...
# 1696859 2018-09-24 23:55:49  2018-09-24    23:55:49
# 1696860 2018-09-24 23:57:14  2018-09-24    23:57:14
# 1696861 2018-09-24 23:57:38  2018-09-24    23:57:38
# 1696862 2018-09-24 23:58:00  2018-09-24    23:58:00
# 1696863 2018-09-24 23:59:20  2018-09-24    23:59:20
#
# [9424 rows x 3 columns]
#
# (9424, 11)

# %% [markdown]
# ###Combine all 183 pkl files

# %%
#import pandas as pd
#import glob
#import os

# Define the directory where your pickle files are stored
# Replace 'path/to/your/pickles' with the actual directory path
pickles_dir = '/content/FD_P2/data'    #'path/to/your/pickles'

# Use glob to find all files ending with .pkl in the specified directory
# This creates a list of file paths to iterate through
pickle_files = glob.glob(os.path.join(pickles_dir, '*.pkl'))

# Check if any files were found
if not pickle_files:
    print(f"No pickle files found in the directory: {pickles_dir}")
else:
    # Initialize an empty list to store individual dataframes
    list_of_dfs = []

    # Iterate over each file path in the list
    for file in pickle_files:
        try:
            # Read the pickle file into a temporary dataframe and append it to the list
            df_temp = pd.read_pickle(file)
            list_of_dfs.append(df_temp)
            print('--------------------------------------------------------')
            print(f"Successfully loaded {file} with {len(df_temp)} records.")
            print('--------------------------------------------------------')
        except Exception as e:
            # Handle potential errors during file reading
            print(f"Error reading file {file}: {e}")

    # Concatenate all dataframes in the list into a single final dataframe
    if list_of_dfs:
        final_dataframe = pd.concat(list_of_dfs, ignore_index=True)

        print("\n--- Summary ---")
        print(f"Total number of files processed: {len(pickle_files)}")
        print(f"Total records in the combined dataframe: {len(final_dataframe)}")
        print("\nCombined dataframe head:")
        print(final_dataframe.head())

        # Optional: Save the combined dataframe to a new pickle file
        # final_dataframe.to_pickle("combined_records.pkl")
        # print("\nCombined dataframe saved to 'combined_records.pkl'")

    else:
        print("No dataframes were successfully loaded. Cannot create a combined dataframe.")
# Out:
# --------------------------------------------------------
# Successfully loaded /content/FD_P2/data/2018-07-22.pkl with 9440 records.
# --------------------------------------------------------
# --------------------------------------------------------
# Successfully loaded /content/FD_P2/data/2018-06-15.pkl with 9448 records.
# --------------------------------------------------------
# --------------------------------------------------------
# Successfully loaded /content/FD_P2/data/2018-07-14.pkl with 9521 records.
# --------------------------------------------------------
# --------------------------------------------------------
# Successfully loaded /content/FD_P2/data/2018-08-11.pkl with 9427 records.
# --------------------------------------------------------
# --------------------------------------------------------
# Successfully loaded /content/FD_P2/data/2018-04-14.pkl with 9557 records.
# --------------------------------------------------------
# ...

# %% [markdown]
# ##EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ###Descriptive Statistics

# %%
final_dataframe.describe(include=['int64','float64'])
# Out:
#        TRANSACTION_ID     TX_AMOUNT      TX_FRAUD  TX_FRAUD_SCENARIO
# count    1.754155e+06  1.754155e+06  1.754155e+06       1.754155e+06
# mean     8.770770e+05  5.363230e+01  8.369272e-03       1.882388e-02
# std      5.063811e+05  4.232649e+01  9.110012e-02       2.113263e-01
# min      0.000000e+00  0.000000e+00  0.000000e+00       0.000000e+00
# 25%      4.385385e+05  2.101000e+01  0.000000e+00       0.000000e+00
# 50%      8.770770e+05  4.464000e+01  0.000000e+00       0.000000e+00
# 75%      1.315616e+06  7.695000e+01  0.000000e+00       0.000000e+00
# max      1.754154e+06  2.628000e+03  1.000000e+00       3.000000e+00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(15,10))
sns.pairplot(final_dataframe)
plt.show()

# %%
final_dataframe.describe(include=['object'])
# Out:
#         CUSTOMER_ID  TERMINAL_ID  TX_TIME_SECONDS  TX_TIME_DAYS
# count       1754155      1754155          1754155       1754155
# unique         4990        10000          1635076           183
# top             382         4018          7992619            90
# freq            767          376                6          9789

# %%
final_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        object
#  3   TERMINAL_ID        object
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    object
#  6   TX_TIME_DAYS       object
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 120.4+ MB

# %%
final_dataframe.to_csv('Fin_Fraud_Detect.csv')

# %% [markdown]
# ###Null Values in each column of the dataframe

# %%
final_dataframe.isnull().sum()
# Out:
# TRANSACTION_ID       0
# TX_DATETIME          0
# CUSTOMER_ID          0
# TERMINAL_ID          0
# TX_AMOUNT            0
# TX_TIME_SECONDS      0
# TX_TIME_DAYS         0
# TX_FRAUD             0
# TX_FRAUD_SCENARIO    0
# dtype: int64

# %% [markdown]
# ###Duplicated records in the DataFrame

# %%
final_dataframe.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_dataframe['TX_FRAUD'].value_counts()
# Out:
# TX_FRAUD
# 0    1739474
# 1      14681
# Name: count, dtype: int64

# %%
final_dataframe['TX_FRAUD_SCENARIO'].value_counts()
# Out:
# TX_FRAUD_SCENARIO
# 0    1739474
# 2       9077
# 3       4631
# 1        973
# Name: count, dtype: int64

# %%
final_dataframe['TX_FRAUD_SCENARIO'].value_counts().sort_index()
# Out:
# TX_FRAUD_SCENARIO
# 0    1739474
# 1        973
# 2       9077
# 3       4631
# Name: count, dtype: int64

# %%
9077+4631+973
# Out:
# 14681

# %%
final_dataframe['TX_AMOUNT'].describe()
# Out:
# count    1.754155e+06
# mean     5.363230e+01
# std      4.232649e+01
# min      0.000000e+00
# 25%      2.101000e+01
# 50%      4.464000e+01
# 75%      7.695000e+01
# max      2.628000e+03
# Name: TX_AMOUNT, dtype: float64

# %%
final_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        object
#  3   TERMINAL_ID        object
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    object
#  6   TX_TIME_DAYS       object
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 120.4+ MB

# %% [markdown]
# #SCENARIO - 1

# %% [markdown]
# #### Any Transaction whose amount is more than 220 is fraud, This is not inspired by a real-world scenario. It provides an obvious fraud pattern that should be detected by any baseline fraud detector. This will be useful to validate the implementation of a fraud detection technique.

# %%
final_dataframe1 = final_dataframe.copy(deep=True)

final_dataframe1["TX_DATETIME"] = pd.to_datetime(final_dataframe1["TX_DATETIME"])
final_dataframe1["hour"] = final_dataframe1["TX_DATETIME"].dt.hour
final_dataframe1["weekday"] = final_dataframe1["TX_DATETIME"].dt.weekday
final_dataframe1["day"] = final_dataframe1["TX_DATETIME"].dt.day

final_dataframe1 = final_dataframe1.drop(columns=["TX_DATETIME"])

# %%
final_dataframe1.shape
# Out:
# (1754155, 11)

# %%
final_dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 11 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   CUSTOMER_ID        int64
#  2   TERMINAL_ID        int64
#  3   TX_AMOUNT          float64
#  4   TX_TIME_SECONDS    object
#  5   TX_TIME_DAYS       object
#  6   TX_FRAUD           int64
#  7   TX_FRAUD_SCENARIO  int64
#  8   hour               int32
#  9   weekday            int32
#  10  day                int32
# dtypes: float64(1), int32(3), int64(5), object(2)
# memory usage: 127.1+ MB

# %%
final_dataframe1[['hour','day','weekday']]
# Out:
#          hour  day  weekday
# 0           0   22        6
# 1           0   22        6
# 2           0   22        6
# 3           0   22        6
# 4           0   22        6
# ...       ...  ...      ...
# 1754150    23   12        6
# 1754151    23   12        6
# 1754152    23   12        6
# 1754153    23   12        6
# 1754154    23   12        6
#
# [1754155 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

for col in ["CUSTOMER_ID", "TERMINAL_ID"]:
    final_dataframe1[col] = pd.to_numeric(LabelEncoder().fit_transform(final_dataframe1[col]))

# %%
final_dataframe1[["CUSTOMER_ID","TERMINAL_ID"]]
# Out:
#          CUSTOMER_ID  TERMINAL_ID
# 0               1389         2530
# 1               4606         4831
# 2               2828         3893
# 3               1712         5745
# 4               3908         6603
# ...              ...          ...
# 1754150         1180         5008
# 1754151         2898         9537
# 1754152         4500         2882
# 1754153         1842         4238
# 1754154         4019         5618
#
# [1754155 rows x 2 columns]

# %%
# Force conversion to numeric
final_dataframe1["TX_TIME_SECONDS"] = pd.to_numeric(final_dataframe1["TX_TIME_SECONDS"], errors="coerce")
final_dataframe1["TX_TIME_DAYS"] = pd.to_numeric(final_dataframe1["TX_TIME_DAYS"], errors="coerce")

# Remove rows that became NaN
#df = df.dropna(subset=["TX_TIME_SECONDS", "TX_TIME_DAYS"])

# %%
X = final_dataframe1.drop(columns=["TX_FRAUD", "TX_FRAUD_SCENARIO"])
y_binary = final_dataframe1["TX_FRAUD"]
y_multi = final_dataframe1["TX_FRAUD_SCENARIO"]

# %%
X.shape
# Out:
# (1754155, 9)

# %%
X.dtypes
# Out:
# TRANSACTION_ID       int64
# CUSTOMER_ID          int64
# TERMINAL_ID          int64
# TX_AMOUNT          float64
# TX_TIME_SECONDS      int64
# TX_TIME_DAYS         int64
# hour                 int32
# weekday              int32
# day                  int32
# dtype: object

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y_binary)

# %%
X_res.dtypes
# Out:
# TRANSACTION_ID       int64
# CUSTOMER_ID          int64
# TERMINAL_ID          int64
# TX_AMOUNT          float64
# TX_TIME_SECONDS      int64
# TX_TIME_DAYS         int64
# hour                 int32
# weekday              int32
# day                  int32
# dtype: object

# %%
X_res
# Out:
#          TRANSACTION_ID  CUSTOMER_ID  TERMINAL_ID   TX_AMOUNT  \
# 0               1074026         1389         2530   21.480000
# 1               1074027         4606         4831   45.460000
# 2               1074028         2828         3893   24.850000
# 3               1074029         1712         5745   66.480000
# 4               1074030         3908         6603   15.610000
# ...                 ...          ...          ...         ...
# 3478943         1731911         1343         5206  561.041707
# 3478944         1642341         1432         8787  140.444002
# 3478945         1008378         3684         7257  201.024812
# 3478946         1139157         1231         6194   25.171225
# 3478947          802321         2653         7296   75.028008
#
#          TX_TIME_SECONDS  TX_TIME_DAYS  hour  weekday  day
# 0                9676822           112     0        6   22
# 1                9676878           112     0        6   22
# ...

# %%
y_res
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 3478943    1
# 3478944    1
# 3478945    1
# 3478946    1
# 3478947    1
# Name: TX_FRAUD, Length: 3478948, dtype: int64

# %%
1754155*2
# Out:
# 3508310

# %%
3478945-3508310
# Out:
# -29365

# %%
29365/2
# Out:
# 14682.5

# %%
from xgboost import XGBClassifier

bin_model = XGBClassifier(
    scale_pos_weight=len(y_binary[y_binary==0]) / len(y_binary[y_binary==1]),
    eval_metric="logloss"
)
bin_model.fit(X_res, y_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
fraud_df = final_dataframe1[final_dataframe1["TX_FRAUD"] == 1]
X_fraud = fraud_df.drop(columns=["TX_FRAUD","TX_FRAUD_SCENARIO"])
y_fraud = fraud_df["TX_FRAUD_SCENARIO"]

y_fraud1 = y_fraud.map({
    1: 0,
    2: 1,
    3: 2
})

multi_model = XGBClassifier(
    objective="multi:softmax",
    num_class=3
)

multi_model.fit(X_fraud, y_fraud1)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_class=3, ...)

# %%
y_fraud.value_counts().sort_index()#fraud_df
# Out:
# TX_FRAUD_SCENARIO
# 1     973
# 2    9077
# 3    4631
# Name: count, dtype: int64

# %%
y_fraud1.value_counts().sort_index()#fraud_df
# Out:
# TX_FRAUD_SCENARIO
# 0     973
# 1    9077
# 2    4631
# Name: count, dtype: int64

# %%
def final_predict(tx):
    p = bin_model.predict(pd.DataFrame([tx]))[0]
    if p == 0:
        return 0
    else:
        print("The Transaction is Fraudulent")
    return multi_model.predict(pd.DataFrame([tx]))[0]

# %% [markdown]
# ###Prediction for Scenario-1

# %%
tx1={
     'TRANSACTION_ID':1074026,
     'CUSTOMER_ID': 1389,
     'TERMINAL_ID': 2530,
     'TX_AMOUNT': 21.480000,
     'TX_TIME_SECONDS': 9676822,
     'TX_TIME_DAYS': 112,
     'hour': 0,
     'weekday': 6,
     'day': 22
}

tx2 = [1074026, 1389, 2530, 21.480000,
       9676822, 112, 0, 6, 22]

# %%
final_predict(tx1) # supply a Dictionary of the features in that order of training
# Out:
# The Transaction is Fraudulent
# np.int32(1)

# %%
#The Transaction is Fraudulent
#np.int32(1)

''' the above result indicates that the example scenario belongs to 9077 class'''
# Out:
# ' the above result indicates that the example scenario belongs to 9077 class'

# %% [markdown]
# #SCENARIO - 2

# %% [markdown]
# #### Every Day, A list of two terminals is drawn at random. All Transactions on these terminals in the next 28 days will be marked as fraudulent. This scenario simulates a criminal use of a terminal, through phishing for example. You could add features that keep track of the number of fraudulent transactions on the terminal to help with this scenario.

# %%
import pandas as pd
import numpy as np

final_df2 = final_dataframe.copy(deep = True)

# Ensure datetime
final_df2['TX_DATETIME'] = pd.to_datetime(final_df2['TX_DATETIME'])
final_df2 = final_df2.sort_values('TX_DATETIME').reset_index(drop=True)

final_df2['TX_FRAUD'] = 0
final_df2['TX_FRAUD_SCENARIO'] = 0

days = final_df2['TX_TIME_DAYS'].unique()

np.random.seed(42)

for day in days:
    terminals_today = np.random.choice(
        final_df2['TERMINAL_ID'].unique(), size=2, replace=False
    )

    mask = (
        (final_df2['TX_TIME_DAYS'] >= day) &
        (final_df2['TX_TIME_DAYS'] <= day + 28) &
        (final_df2['TERMINAL_ID'].isin(terminals_today))
    )

    final_df2.loc[mask, 'TX_FRAUD'] = 1
    final_df2.loc[mask, 'TX_FRAUD_SCENARIO'] = 2

# %%
final_df2
# Out:
#          TRANSACTION_ID         TX_DATETIME CUSTOMER_ID TERMINAL_ID  \
# 0                     0 2018-04-01 00:00:31         596        3156
# 1                     1 2018-04-01 00:02:10        4961        3412
# 2                     2 2018-04-01 00:07:56           2        1365
# 3                     3 2018-04-01 00:09:29        4128        8737
# 4                     4 2018-04-01 00:10:34         927        9906
# ...                 ...                 ...         ...         ...
# 1754150         1754150 2018-09-30 23:56:36         161         655
# 1754151         1754151 2018-09-30 23:57:38        4342        6181
# 1754152         1754152 2018-09-30 23:58:21         618        1502
# 1754153         1754153 2018-09-30 23:59:52        4056        3067
# 1754154         1754154 2018-09-30 23:59:57        3542        9849
#
#          TX_AMOUNT TX_TIME_SECONDS TX_TIME_DAYS  TX_FRAUD  TX_FRAUD_SCENARIO
# ...

# %%
final_df2[['TX_FRAUD','TX_FRAUD_SCENARIO']].value_counts()
# Out:
# TX_FRAUD  TX_FRAUD_SCENARIO
# 0         0                    1744792
# 1         2                       9363
# Name: count, dtype: int64

# %%
final_df2['TX_DATETIME'] = pd.to_datetime(final_df2['TX_DATETIME'])

# %%
final_df2 = final_df2.sort_values(['TERMINAL_ID', 'TX_DATETIME'])

#final_df2['TX_DATETIME'] = pd.to_datetime(final_df2['TX_DATETIME'])

final_df2 = final_df2.sort_values(['TERMINAL_ID','TX_DATETIME'])

final_df2 = final_df2.set_index('TX_DATETIME')


final_df2['TERM_FRAUD_COUNT_1D'] = (
    final_df2.groupby('TERMINAL_ID')['TX_FRAUD']
    .rolling('1D')#, on=final_df2['TX_DATETIME'])
    .sum()
    .reset_index(level=0, drop=True)
)

final_df2['TERM_FRAUD_COUNT_7D'] = (
    final_df2.groupby('TERMINAL_ID')['TX_FRAUD']
    .rolling('7D')
    .sum()
    .reset_index(level=0, drop=True)
)

final_df2['TERM_TX_COUNT_7D'] = (
    final_df2.groupby('TERMINAL_ID')['TX_AMOUNT']
    .rolling('7D')
    .count()
    .reset_index(level=0, drop=True)
)

final_df2['TERM_FRAUD_RATIO_7D'] = (
    final_df2['TERM_FRAUD_COUNT_7D'] / final_df2['TERM_TX_COUNT_7D']
).fillna(0)

# %%
final_df2.index
# Out:
# DatetimeIndex(['2018-04-02 01:00:01', '2018-04-02 09:49:55',
#                '2018-04-03 12:14:41', '2018-04-05 16:47:41',
#                '2018-04-07 06:05:21', '2018-04-07 10:18:42',
#                '2018-04-07 14:37:49', '2018-04-09 13:36:59',
#                '2018-04-10 07:53:35', '2018-04-10 10:19:15',
#                ...
#                '2018-09-22 21:10:25', '2018-09-24 08:16:16',
#                '2018-09-24 12:07:16', '2018-09-25 03:18:50',
#                '2018-09-26 08:58:28', '2018-09-28 15:34:24',
#                '2018-09-30 05:36:08', '2018-09-30 09:00:10',
#                '2018-09-30 17:47:37', '2018-09-30 20:50:32'],
#               dtype='datetime64[ns]', name='TX_DATETIME', length=1754155, freq=None)

# %%
features = [
    'TX_TIME_SECONDS',
    'TX_TIME_DAYS',
    'TERM_FRAUD_COUNT_1D',
    'TERM_FRAUD_COUNT_7D',
    'TERM_TX_COUNT_7D',
    'TERM_FRAUD_RATIO_7D'
]

X = final_df2[features]
y = final_df2['TX_FRAUD']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y
)

model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    class_weight='balanced',
    random_state=42
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    174480
#            1       0.99      1.00      0.99       936
#
#     accuracy                           1.00    175416
#    macro avg       0.99      1.00      1.00    175416
# weighted avg       1.00      1.00      1.00    175416

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.pairplot(final_df2[features])
plt.show()

# %%
finaldf2corr = final_df2[features].corr()

# %%
plt.figure(figsize=(15,10))
plt.title("Feature Map", size=45, color='magenta')
sns.heatmap(finaldf2corr, vmax = 1.0, vmin = 0.0, annot = True, annot_kws = {'fontsize':20, 'color':'red'})
plt.xticks(size=25, color='green')
plt.yticks(size=25, color='green')
plt.show()

# %% [markdown]
# # SCENARIO - 3

# %% [markdown]
# ####Every Day a list of 3 customers is drawn at random. In the next 14 Days, 1/3 of their transactions have their amounts multiplied by 5 and marked as fraudulent. This scenario simulates a card-not-present fraud where the Credentials of a customer have been leaked. The customer continues to make transactions, and transactions of higher values are made by the fraudsters whotries to maximize gains,
# You could add features that keep track of the spending habits of the customer for this scenario

# %%
import pandas as pd
import numpy as np

np.random.seed(42)   # for reproducibility

# ---- Example DataFrame (replace with your real df) ----
df = pd.DataFrame({
    "cust_id": np.random.randint(1, 100, 1000),
    "amount": np.random.randint(100, 1000, 1000),
    "f2": np.random.randn(1000),
    "f3": np.random.randn(1000),
    "f4": np.random.randn(1000),
    "f5": np.random.randn(1000),
    "f6": np.random.randn(1000),
})

# Add date column (if you already have one, remove this)
df["txn_date"] = pd.Timestamp.today().normalize()

# Add fraud flag column
df["fraud_flag"] = 0

# ------------------------------------------------------
# STEP 1: Select 3 random customers
# ------------------------------------------------------
selected_customers = np.random.choice(df["cust_id"].unique(), size=3, replace=False)
print("Selected Customers:", selected_customers)

df_sub = df[df["cust_id"].isin(selected_customers)]

# ------------------------------------------------------
# STEP 2: Select 1/3rd of their records
# ------------------------------------------------------
n = int(len(df_sub) / 3)
fraud_idx = np.random.choice(df_sub.index, size=n, replace=False)

# ------------------------------------------------------
# STEP 3: Assign random dates in next 14 days
# ------------------------------------------------------
start_date = pd.Timestamp.today().normalize()
random_days = np.random.randint(1, 15, size=n)
df.loc[fraud_idx, "txn_date"] = start_date + pd.to_timedelta(random_days, unit="D")

# ------------------------------------------------------
# STEP 4: Multiply amount by 5
# ------------------------------------------------------
df.loc[fraud_idx, "amount"] *= 5

# ------------------------------------------------------
# STEP 5: Mark as Fraud
# ------------------------------------------------------
df.loc[fraud_idx, "fraud_flag"] = 1

# ------------------------------------------------------
# RESULTS
# ------------------------------------------------------
print("\nTotal Fraud Records:", df["fraud_flag"].sum())
print("\nSample Fraud Records:")
print(df[df["fraud_flag"] == 1].head())
# Out:
# Selected Customers: [59 62 88]
#
# Total Fraud Records: 12
#
# Sample Fraud Records:
#      cust_id  amount        f2        f3        f4        f5        f6  \
# 30        59    1640  1.183414 -1.592601 -1.076497 -0.411855 -1.363356
# 39        62    4730 -0.274032 -1.382867  0.197326 -0.832361 -1.239555
# 112       88    1975  0.268217 -0.343411  0.538133 -0.012644  0.126514
# 184       62    4665  0.302399  0.301044  0.527537 -0.950862  1.062357
# 188       62    4705 -0.364202  0.449609 -1.044574 -0.544364 -0.815711
#
#       txn_date  fraud_flag
# 30  2026-02-25           1
# 39  2026-02-25           1
# 112 2026-02-20           1
# 184 2026-02-14           1
# 188 2026-02-13           1

# %% [markdown]
# ####Creating New Features for Scenario 3

# %%
final_df3 = final_dataframe.copy(deep=True)

# %%
final_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        object
#  3   TERMINAL_ID        object
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    object
#  6   TX_TIME_DAYS       object
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 120.4+ MB

# %%
final_df3['TX_TIME_SECONDS'] = pd.to_numeric(final_df3['TX_TIME_SECONDS'], errors ='coerce')
final_df3['TX_TIME_DAYS'] = pd.to_numeric(final_df3['TX_TIME_DAYS'], errors ='coerce')

# %%
final_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        object
#  3   TERMINAL_ID        object
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    int64
#  6   TX_TIME_DAYS       int64
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(2)
# memory usage: 120.4+ MB

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['CUSTOMER_ID','TERMINAL_ID']:
  final_df3[col] = pd.to_numeric(LabelEncoder().fit_transform(final_df3[col]))

# %%
final_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        int64
#  3   TERMINAL_ID        int64
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    int64
#  6   TX_TIME_DAYS       int64
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(7)
# memory usage: 120.4 MB

# %%
final_df3['TX_DATETIME'] = pd.to_datetime(final_df3['TX_DATETIME'])

# %%
final_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        int64
#  3   TERMINAL_ID        int64
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    int64
#  6   TX_TIME_DAYS       int64
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
# dtypes: datetime64[ns](1), float64(1), int64(7)
# memory usage: 120.4 MB

# %% [markdown]
# ####Feature Selection

# %%
final_df3 = final_df3.sort_values(['CUSTOMER_ID','TX_DATETIME'])

# %%
# Calculating Rolling Average Amount

final_df3['CUST_AVG_AMOUNT'] = final_df3.groupby('CUSTOMER_ID')['TX_AMOUNT'].transform(lambda x:x.expanding().mean())

# %%
final_df3['CUST_AVG_AMOUNT'].sort_values()
# Out:
# 559400       0.210000
# 211249       0.230000
# 556037       0.270000
# 562054       0.300000
# 556483       0.360000
#               ...
# 726574     244.738000
# 1714223    245.100000
# 1195043    253.517143
# 724555     263.836667
# 720768     287.465000
# Name: CUST_AVG_AMOUNT, Length: 1754155, dtype: float64

# %%
import numpy as np

random_customers = np.random.choice(
    final_df3['CUSTOMER_ID'].unique(),
    size=5,
    replace=False
)
print(random_customers)
# Out:
# [4336 4383 2929 1210  370]

# %%
#sample_customers = final_df3['CUSTOMER_ID'].unique()[:5]

for cust_id in random_customers:
    g = final_df3[final_df3['CUSTOMER_ID'] == cust_id]

    plt.figure()
    plt.plot(g['TX_DATETIME'], g['TX_AMOUNT'], label='TX_AMOUNT')
    plt.plot(g['TX_DATETIME'], g['CUST_AVG_AMOUNT'], linestyle='--', label='CUST_AVG_AMOUNT')

    plt.title(f'Customer ID: {cust_id}', color='magenta', size=25)
    plt.xlabel('Transaction Time', color = 'green', size = 15)
    plt.ylabel('Amount', color = 'green', size =  15)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Now calc Z-Score, How much the cust_avg_amount deviate from their usual, (current-mean)/std

# %%
#Calc Customer Stats

Cust_Stats = final_df3.groupby('CUSTOMER_ID')['TX_AMOUNT'].agg(['mean', 'std']).fillna(0)
Cust_Stats
# Out:
#                    mean        std
# CUSTOMER_ID
# 0             61.448750  28.787885
# 1             51.670817  36.201596
# 2             81.724882  36.743394
# 3             12.820000   5.489647
# 4             80.482106  37.775365
# ...                 ...        ...
# 4985          55.230086  25.730390
# 4986          14.603502   6.904591
# 4987          58.414403  26.107804
# 4988         100.091070  47.683786
# 4989          40.215971  18.460616
#
# [4990 rows x 2 columns]

# %%
final_df3 = final_df3.merge(Cust_Stats, on = 'CUSTOMER_ID', suffixes = ('', '_stats'))
final_df3.head(5)
# Out:
#    TRANSACTION_ID         TX_DATETIME  CUSTOMER_ID  TERMINAL_ID  TX_AMOUNT  \
# 0            1758 2018-04-01 07:19:05            0         6076     123.59
# 1            8275 2018-04-01 18:00:16            0          858      77.34
# 2            8640 2018-04-01 19:02:02            0         6698      46.51
# 3           12169 2018-04-02 08:51:06            0         6569      54.72
# 4           15764 2018-04-02 14:05:38            0         7707      63.30
#
#    TX_TIME_SECONDS  TX_TIME_DAYS  TX_FRAUD  TX_FRAUD_SCENARIO  \
# 0            26345             0         0                  0
# 1            64816             0         0                  0
# 2            68522             0         0                  0
# 3           118266             1         0                  0
# 4           137138             1         0                  0
#
#    CUST_AVG_AMOUNT      mean        std
# 0          123.590  61.44875  28.787885
# 1          100.465  61.44875  28.787885
# ...

# %%
final_df3['TX_Z_SCORE'] = (final_df3['TX_AMOUNT'] - final_df3['mean'])/(final_df3['std'])
final_df3['TX_Z_SCORE'].head(5)
# Out:
# 0    2.158590
# 1    0.552012
# 2   -0.518925
# 3   -0.233735
# 4    0.064307
# Name: TX_Z_SCORE, dtype: float64

# %%
final_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1754155 entries, 0 to 1754154
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TRANSACTION_ID     int64
#  1   TX_DATETIME        datetime64[ns]
#  2   CUSTOMER_ID        int64
#  3   TERMINAL_ID        int64
#  4   TX_AMOUNT          float64
#  5   TX_TIME_SECONDS    int64
#  6   TX_TIME_DAYS       int64
#  7   TX_FRAUD           int64
#  8   TX_FRAUD_SCENARIO  int64
#  9   CUST_AVG_AMOUNT    float64
#  10  mean               float64
#  11  std                float64
#  12  TX_Z_SCORE         float64
# dtypes: datetime64[ns](1), float64(5), int64(7)
# memory usage: 174.0 MB

# %%
for cust_id in random_customers:
    g = final_df3[final_df3['CUSTOMER_ID'] == cust_id]

    plt.figure()
    plt.plot(g['TX_DATETIME'], g['TX_AMOUNT'], label='TX_AMOUNT', color= 'orange')
    plt.plot(g['TX_DATETIME'], g['CUST_AVG_AMOUNT'], linestyle='--', label='CUST_AVG_AMOUNT', color='red')
    plt.plot(g['TX_DATETIME'], g['TX_Z_SCORE'], linestyle ='-.', label='TX_Z_SCORE', color='cyan')

    plt.title(f'Customer ID: {cust_id}', color='magenta', size=25)
    plt.xlabel('Transaction Time', color = 'green', size = 15)
    plt.ylabel('Amount', color = 'green', size =  15)
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ####Checking The Transaction Velocity (Count in Last 1D)

# %%
final
