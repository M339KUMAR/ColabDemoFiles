# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/GCAF/Load_Readwebhtml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CSV File loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

Df = pd.DataFrame(np.random.rand(3,3))

Df
# Out:
#           0        1         2
# 0  0.441094  0.98807  0.313135
# 1  0.903497  0.18850  0.601245
# 2  0.194875  0.25262  0.824200

# %%
Df.describe()
# Out:
#               0         1         2
# count  3.000000  3.000000  3.000000
# mean   0.598702  0.718658  0.347382
# std    0.260795  0.248972  0.286111
# min    0.305362  0.489935  0.030180
# 25%    0.495882  0.586060  0.228091
# 50%    0.686402  0.682184  0.426003
# 75%    0.745373  0.833019  0.505983
# max    0.804343  0.983855  0.585963

# %%
Df.corr()
# Out:
#           0         1         2
# 0  1.000000 -0.100707  0.998475
# 1 -0.100707  1.000000 -0.155471
# 2  0.998475 -0.155471  1.000000

# %%
Df.plot(kind='barh')
plt.xticks(size= 30, rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0'),
#   Text(1.2000000000000002, 0, '1.2')])

# %%
Df.plot(kind='bar')
plt.xticks(size= 30, rotation=45)
plt.yticks(size= 30, rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
Df
# Out:
#           0         1         2
# 0  0.244836  0.415230  0.050543
# 1  0.552393  0.803850  0.996591
# 2  0.093456  0.951557  0.690229

# %%
Df.describe().hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: >]], dtype=object)

# %% [markdown]
# #Html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#READING and making a
#Dataframe directly from web page
#into pandas dataframe
#HTML FILE

#Google search stribg ::::::::"sample html tables"

#https://www.w3schools.com/html/html_tables.asp

Df = pd.read_html('https://www.w3schools.com/html/html_tables.asp')

Df
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,
#            Tag                                        Description
#  0     <table>                                    Defines a table
#  1        <th>                   Defines a header cell in a table
#  2        <tr>                           Defines a row in a table
#  3        <td>                          Defines a cell in a table
#  4   <caption>                            Defines a table caption
#  5  <colgroup>  Specifies a group of one or more columns in a ...
#  6       <col>  Specifies column properties for each column wi...
# ...

# %%
Df[0]        # 1st DataFrame
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
Df[1]     #2nd DataFrame
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
Df[0].describe()
# Out:
#                     Company       Contact  Country
# count                     6             6        6
# unique                    6             6        6
# top     Alfreds Futterkiste  Maria Anders  Germany
# freq                      1             1        1

# %%
Df[1].describe()
# Out:
#             Tag      Description
# count        10               10
# unique       10               10
# top     <table>  Defines a table
# freq          1                1

# %%
Df[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  6 non-null      object
#  1   Contact  6 non-null      object
#  2   Country  6 non-null      object
# dtypes: object(3)
# memory usage: 272.0+ bytes

# %%
Df[0]['Company']
# Out:
# 0             Alfreds Futterkiste
# 1      Centro comercial Moctezuma
# 2                    Ernst Handel
# 3                  Island Trading
# 4    Laughing Bacchus Winecellars
# 5    Magazzini Alimentari Riuniti
# Name: Company, dtype: object

# %%
Df[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tag          10 non-null     object
#  1   Description  10 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
Df[1]['Tag']
# Out:
# 0       <table>
# 1          <th>
# 2          <tr>
# 3          <td>
# 4     <caption>
# 5    <colgroup>
# 6         <col>
# 7       <thead>
# 8       <tbody>
# 9       <tfoot>
# Name: Tag, dtype: object

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
Espn = pd.read_html('https://www.espncricinfo.com/series/icc-cricket-world-cup-2023-24-1367856/india-vs-australia-final-1384439/points-table-standings')
Espn
# Out:
# [                                                TEAMS  \
#  0                                              1India
#  1   WNovember 12, 2023, 45th Match, India vs Nethe...
#  2                                       2South Africa
#  3   WNovember 10, 2023, 42nd Match, South Africa v...
#  4                                          3Australia
#  5   WNovember 11, 2023, 43rd Match, Australia vs B...
#  6                                        4New Zealand
#  7   WNovember 09, 2023, 41st Match, New Zealand vs...
#  8                                           5Pakistan
#  9   LNovember 11, 2023, 44th Match, Pakistan vs En...
#  10                                       6Afghanistan
#  11  LNovember 10, 2023, 42nd Match, Afghanistan vs...
#  12                                           7England
#  13  WNovember 11, 2023, 44th Match, England vs Pak...
#  14                                        8Bangladesh
#  15  LNovember 11, 2023, 43rd Match, Bangladesh vs ...
# ...

# %%
Espn[4]
# Out:
#   TEAM  M  W  L  PT    NRR
# 0  IND  9  9  0  18  2.570
# 1   SA  9  7  2  14  1.261
# 2  AUS  9  7  2  14  0.841
# 3   NZ  9  5  4  10  0.743
# 4  PAK  9  4  5   8 -0.199
# 5  AFG  9  4  5   8 -0.336
# 6  ENG  9  3  6   6 -0.572
# 7  BAN  9  2  7   4 -1.087
# 8   SL  9  2  7   4 -1.419
# 9  NED  9  2  7   4 -1.825

# %%
Colors= (1,2,3,4,5,6,7,8,9)

ax= Espn[4].PT.plot(kind='bar', title = 'ICC CWC-23', xlabel= ['I','SA','A','N','P','Af','E','B','SL','NED'], color= 'orange', edgecolor='blue',lw=2)
Espn[4].to_csv('../content/sample_data/icccwc2023finalpointstable.csv')
ax.hlines(9.0,-0.1,10,linestyle='dashed', color='red')
ax.vlines(5.0, -0.9,20.0, linestyle= 'dashed', color='green')
ax.annotate('Average', (5.0,9.0), fontsize= 20)
#ax.label('Ind','Sa','Aus','Nz','Pak','Afg','Eng','Ban','Sl','Ned')
ax.legend(labels=[  'Ind','Sa','Aus','Nz','Pak','Afg','Eng','Ban','Sl','Ned'  ])
ax.grid(True)
ax.set_xlabel('Country',size= 20)
ax.set_ylabel('Total Num of Points Won',size=20)
ax.set_title('Overall Points Table Standings', size = 30)
#ax.axhspan((-0.2,6.0),(0,1))
# Out:
# Text(0.5, 1.0, 'Overall Points Table Standings')

# %%
Espn[4].PT.mean()
# Out:
# 9.0

# %%
Espn[3]
# Out:
#    WKT  RUNS         PLAYERS           PLAYERS.1
# 0  1st    16    David Warner         Travis Head
# 1  2nd    25  Mitchell Marsh         Travis Head
# 2  3rd     6    Steven Smith         Travis Head
# 3  4th   192     Travis Head  Marnus Labuschagne
# 4  5th     2   Glenn Maxwell  Marnus Labuschagne

# %%
Espn[2]
# Out:
#       PLAYER NAME   O  M   R  W  Econ
# 0       JJ Bumrah   9  2  43  2  4.77
# 1  Mohammed Shami   7  1  47  1  6.71
# 2       RA Jadeja  10  0  43  0  4.30
# 3   Kuldeep Yadav  10  0  56  0  5.60
# 4  Mohammed Siraj   7  0  45  1  6.42

# %%
Espn[1]
# Out:
#      PLAYER NAME        PLAYER NAME.1                    R  \
# 0      DA Warner               caught                    7
# 1        TM Head               caught                  137
# 2       MR Marsh               caught                   15
# 3      SPD Smith                  lbw                    4
# 4  M Labuschagne              not out                   58
# 5     GJ Maxwell              not out                    2
# 6         Extras    (b 5, lb 2, w 11)    (b 5, lb 2, w 11)
# 7          Total  241(4 wkts; 43 ovs)  241(4 wkts; 43 ovs)
#
#                      B
# 0                    3
# 1                  120
# 2                   15
# 3                    9
# 4                  110
# 5                    1
# 6    (b 5, lb 2, w 11)
# 7  241(4 wkts; 43 ovs)

# %%
Espn[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TEAMS        20 non-null     object
#  1   M            20 non-null     object
#  2   W            20 non-null     object
#  3   L            20 non-null     object
#  4   T            20 non-null     object
#  5   N/R          20 non-null     object
#  6   PT           20 non-null     object
#  7   NRR          20 non-null     object
#  8   Series Form  20 non-null     object
#  9   Next         20 non-null     object
#  10  For          20 non-null     object
#  11  Against      20 non-null     object
#  12  Unnamed: 12  10 non-null     object
#  13  Unnamed: 13  10 non-null     object
#  14  Unnamed: 14  10 non-null     object
#  15  Unnamed: 15  10 non-null     object
#  16  Unnamed: 16  10 non-null     object
#  17  Unnamed: 17  10 non-null     object
# ...

# %% [markdown]
# #loading jnbk procesed csv file from mobile

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.axes
# %matplotlib inline

Df=pd.read_csv('/content/sample_data/icccwc2023finalpointstable.csv')
Df
# Out:
#    Unnamed: 0 TEAM  M  W  L  PT    NRR
# 0           0  IND  9  9  0  18  2.570
# 1           1   SA  9  7  2  14  1.261
# 2           2  AUS  9  7  2  14  0.841
# 3           3   NZ  9  5  4  10  0.743
# 4           4  PAK  9  4  5   8 -0.199
# 5           5  AFG  9  4  5   8 -0.336
# 6           6  ENG  9  3  6   6 -0.572
# 7           7  BAN  9  2  7   4 -1.087
# 8           8   SL  9  2  7   4 -1.419
# 9           9  NED  9  2  7   4 -1.825

# %%
Df.describe()
# Out:
#        Unnamed: 0     M          W          L         PT        NRR
# count    10.00000  10.0  10.000000  10.000000  10.000000  10.000000
# mean      4.50000   9.0   4.500000   4.500000   9.000000  -0.002300
# std       3.02765   0.0   2.460804   2.460804   4.921608   1.352353
# min       0.00000   9.0   2.000000   0.000000   4.000000  -1.825000
# 25%       2.25000   9.0   2.250000   2.500000   4.500000  -0.958250
# 50%       4.50000   9.0   4.000000   5.000000   8.000000  -0.267500
# 75%       6.75000   9.0   6.500000   6.750000  13.000000   0.816500
# max       9.00000   9.0   9.000000   7.000000  18.000000   2.570000

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     int64
#  1   TEAM        10 non-null     object
#  2   M           10 non-null     int64
#  3   W           10 non-null     int64
#  4   L           10 non-null     int64
#  5   PT          10 non-null     int64
#  6   NRR         10 non-null     float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 688.0+ bytes

# %%
sns.lmplot(data=Df, x ='M', y='PT', hue='TEAM')
plt.xlabel('MATCHES', size=15)
plt.ylabel('POINTS', size=20)
plt.show()

# %%
sns.regplot(data=Df, x ='M', y='PT' )
# Out:
# <Axes: xlabel='M', ylabel='PT'>

# %%
sns.countplot(Df)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.boxplot(Df)
# Out:
# <Axes: >

# %%
sns.heatmap(Df[['M','W','PT','NRR']], cmap='nipy_spectral', vmin=0,vmax=20, annot=True, lw=0.5)
# Out:
# <Axes: >

# %%
Df[['M','W','PT','NRR']].corr()
# Out:
#       M         W        PT       NRR
# M   NaN       NaN       NaN       NaN
# W   NaN  1.000000  1.000000  0.973076
# PT  NaN  1.000000  1.000000  0.973076
# NRR NaN  0.973076  0.973076  1.000000

# %%
X=Df.corr()
Y=np.triu(X)
sns.heatmap(X, mask=Y, square=True, cmap='crest', vmin=-1, vmax=1.0, annot=True, lw= 3.0)
# Out:
# <ipython-input-13-754f1ee8c670>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   X=Df.corr()
# <Axes: >

# %%
Grid_plot = plt.GridSpec(2, 3, wspace = 0.8, hspace = 0.6)

plt.subplot(Grid_plot[0, 0])
plt.subplot(Grid_plot[0, 1:])
plt.subplot(Grid_plot[1, :2])
plt.subplot(Grid_plot[1, 2])
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.axes

df = pd.DataFrame({'team': ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'],
                   'points': [19, 12, 15, 14, 19, 23, 25, 29],
                   'assists': [13, 15, 11, 8, 6, 8, 11, 14],
                   'rebounds': [11, 7, 8, 12, 13, 7, 6, 8],
                   'blocks': [1, 2, 2, 3, 5, 4, 3, 3]})
#set seaborn plotting aesthetics as default
sns.set()

#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(2, 2)

fig.suptitle("Group plots:", size= 20)
#create boxplot in each subplot
sns.boxplot(data=df,x='team',y='points', ax=axes[0,0])
sns.boxplot(data=df, x='team', y='assists', ax=axes[0,1])
sns.boxplot(data=df, x='team', y='rebounds', ax=axes[1,0])
sns.boxplot(data=df, x='team', y='blocks', ax=axes[1,1])
# Out:
# <Axes: xlabel='team', ylabel='blocks'>

# %%
fig, ax  =plt.subplots(2,2,figsize=(10,8))

plt.subplots_adjust(left=0.1,  bottom=0.1,
                                    right=0.9,   top=0.9,
                                    wspace=1.0, hspace=1.0)

ax[0,0].plot(Df.NRR, Df.M, 'r')

ax[0,1].plot(Df.M, Df.W, 'g')

ax[1,0].plot(Df.NRR, Df.L,'b')

ax[1,1].plot(Df.M, Df.L, 'orange')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure()

plt.subplots_adjust(left=0.1,  bottom=0.1,
                                    right=0.9,   top=0.9,
                                    wspace=1.0, hspace=1.0)


plt.subplot(2, 2, 1)
plt.plot(Df.NRR, Df.M,'r', lw=2.0)

plt.subplot(2, 2, 2)
plt.plot(Df.M, Df.W, 'g', lw=3.0)

plt.subplot(2, 2, 3)
plt.plot(Df.NRR, Df.L, 'pink', lw=4.0)

plt.subplot(2, 2, 4)
plt.plot(Df.M, Df.L, 'orange', lw=5.0)

plt.show()

# %%
X=[1,2,3,4,5,6,7,8,9]
Y= [x*x for x in X]
Y

fig = plt.figure(figsize=(20,20))

plt.subplots_adjust(left=0.1,  bottom=0.1,
                                    right=0.9,   top=0.9,
                                    wspace=1.0, hspace=1.0)
plt.subplot(2,2,1)
plt.plot(X,Y, 'r', lw=5.0)

plt.subplot(2,2,2)
plt.plot(X, np.power(X,3), 'g', lw=5.0)

plt.subplot(2,2,3)
plt.plot(X, np.power(X,4), 'pink', lw=5.0)

plt.subplot(2,2,4)
plt.plot(X, np.power(X,5), 'orange', lw=5.0)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,10))
#fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True)
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True)
ax1, ax2, ax3, ax4 = axes.flatten()

plt.subplots_adjust(left=0.1,  bottom=0.1,
                                    right=0.9,   top=0.9,
                                    wspace=0.1, hspace=0.1)

ax1.plot(range(10), 'r')
ax2.plot(range(10), 'b')
ax3.plot(range(10), 'g')
ax4.plot(range(10), 'k')

plt.show()

# %%
import pandas as pd

# %%
Dfbe10_ai= pd.read_html("https://docs.google.com/spreadsheets/u/0/d/16rHy8mrX8qEyPbloDXeIao1whoiYqLzpefc813yKXA8/htmlview#")

# %%
Dfbe10_ai
# Out:
# [       Unnamed: 0                               A  \
#  0             1.0                            Name
#  1             NaN                             NaN
#  2             2.0                       Mohd amir
#  3             3.0                G . dinesh varma
#  4             4.0     Bhushan narendrasing girase
#  ...           ...                             ...
#  32076     32076.0                   Darshita jain
#  32077     32077.0                   Soham goswami
#  32078     32078.0                     Sajid ahmad
#  32079     32079.0                   Shakib mallik
#  32080     32080.0  Annam yuva sri pardha rama sai
#
#                                      C  \
#  0                         Certificate
#  1                                 NaN
#  2                           Mohd amir
#  3                    G . dinesh varma
#  4         Bhushan narendrasing girase
#  ...                               ...
#  32076                   Darshita jain
# ...

# %%
Dfbe10_ai[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32081 entries, 0 to 32080
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32080 non-null  float64
#  1   A           32080 non-null  object
#  2   C           32080 non-null  object
#  3   D           1 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 1002.7+ KB

# %%
X=Dfbe10_ai[0][Dfbe10_ai[0]['A'].str.contains('praveen', na=False)]
X
# Out:
#        Unnamed: 0                                  A  \
# 29           29.0             Sai praveen veeraboina
# 542         542.0  Renduchintala sai santosh praveen
# 1265       1265.0          Solomon praveen kuchipudi
# 3633       3633.0                       Jada praveen
# 4335       4335.0                     Karike praveen
# 4938       4938.0                      Jayapraveen g
# 4974       4974.0              Thummala praveenkumar
# 5122       5122.0             Sai praveen suraparaju
# 5909       5909.0              M praveen kumar reddy
# 7391       7391.0       Venkata jaya praveen potnuru
# 8535       8535.0                      Pandi praveen
# 9130       9130.0                          R praveen
# 11344     11344.0                Pankaj praveen ekka
# 12085     12085.0              Gummala praveen kumar
# 12331     12331.0            Duvvarapu praveeneswari
# 13213     13213.0        Sangati praveen kumar reddy
# 14641     14641.0              Vidhan praveen tayade
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 29 to 27777
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  29 non-null     float64
#  1   A           29 non-null     object
#  2   C           29 non-null     object
#  3   D           0 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 1.1+ KB

# %%
Dfbe10_ai[0].to_csv('/content/sample_data/BE10AIWS.csv')

X.to_csv("/content/sample_data/AITOOLSWS.csv")
