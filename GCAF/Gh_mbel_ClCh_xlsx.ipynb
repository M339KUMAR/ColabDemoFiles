# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/GCAF/Gh_mbel_ClCh_xlsx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ClimateCh_df= pd.read_excel('/content/sample_data/climate_change.xls')
ClimateCh_df.columns
# Out:
# Index(['Country code', 'Country name',  'Series code',  'Series name',
#               'SCALE',     'Decimals',           1990,           1991,
#                  1992,           1993,           1994,           1995,
#                  1996,           1997,           1998,           1999,
#                  2000,           2001,           2002,           2003,
#                  2004,           2005,           2006,           2007,
#                  2008,           2009,           2010,           2011],
#       dtype='object')

# %%
ClimateCh_df.iloc[0:1, 0:28]
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals      1990 1991 1992  \
# 0  Land area below 5m (% of land area)     0        1  29.57481   ..   ..
#
#   1993  ... 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
# 0   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
#
# [1 rows x 28 columns]

# %%
ClimateCh_df.loc[0:1]
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
# 1          ADO      Andorra  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals      1990 1991 1992  \
# 0  Land area below 5m (% of land area)     0        1  29.57481   ..   ..
# 1  Land area below 5m (% of land area)     0        1         0   ..   ..
#
#   1993  ... 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
# 0   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 1   ..  ...   ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
#
# [2 rows x 28 columns]

# %%
ClimateCh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13512 entries, 0 to 13511
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country code  13512 non-null  object
#  1   Country name  13512 non-null  object
#  2   Series code   13512 non-null  object
#  3   Series name   13512 non-null  object
#  4   SCALE         13512 non-null  object
#  5   Decimals      13512 non-null  object
#  6   1990          10017 non-null  object
#  7   1991          10017 non-null  object
#  8   1992          10017 non-null  object
#  9   1993          10017 non-null  object
#  10  1994          10017 non-null  object
#  11  1995          10017 non-null  object
#  12  1996          10017 non-null  object
#  13  1997          10017 non-null  object
#  14  1998          10017 non-null  object
#  15  1999          10017 non-null  object
#  16  2000          10017 non-null  object
#  17  2001          10017 non-null  object
# ...

# %%
ClimateCh_df['Country code'].describe()
# Out:
# count     13512
# unique      233
# top         ABW
# freq         58
# Name: Country code, dtype: object

# %%
Unemp_df= pd.read_csv('/content/sample_data/unemployment.csv')
Unemp_df.head(2)
# Out:
#          date  unemployment state
# 0  1976-01-01           9.1    NM
# 1  1976-02-01           8.9    NM

# %%
Unemp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7358 entries, 0 to 7357
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          7358 non-null   object
#  1   unemployment  7358 non-null   float64
#  2   state         7358 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 172.6+ KB

# %%
Unemp_df.columns
# Out:
# Index(['date', 'unemployment', 'state'], dtype='object')

# %%
Unemp_df['state'].isna().sum()
# Out:
# 0

# %%
Unemp_df.describe()
# Out:
#        unemployment
# count   7358.000000
# mean       6.086178
# std        2.073988
# min        1.800000
# 25%        4.500000
# 50%        5.800000
# 75%        7.300000
# max       17.700000

# %%
ClimateCh_df.describe()
# Out:
#        Country code Country name     Series code  \
# count         13512        13512           13512
# unique          233          233              58
# top             ABW        Aruba  AG.LND.EL5M.ZS
# freq             58           58             233
#
#                                 Series name  SCALE  Decimals   1990   1991  \
# count                                 13512  13512     13512  10017  10017
# unique                                   58      2         3   4355   3398
# top     Land area below 5m (% of land area)      0         1     ..     ..
# freq                                    233  10017      5823   5163   6520
#
#          1992   1993  ...   2002   2003   2004   2005   2006   2007   2008  \
# count   10017  10017  ...  10017  10017  10017  10017  10017  10017  10017
# unique   3523   3583  ...   3877   3869   4007   4484   4008   4047   4080
# top        ..     ..  ...     ..     ..     ..     ..     ..     ..     ..
# ...

# %%
ClimateCh_df['Country code'].unique()
# Out:
# array(['ABW', 'ADO', 'AFG', 'AGO', 'ALB', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COG', 'COK', 'COL', 'COM', 'CPV', 'CRI',
#        'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK',
#        'DOM', 'DZA', 'EAP', 'ECA', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP',
#        'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR',
#        'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD',
#        'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HRV', 'HTI',
#        'HUN', 'IDN', 'IMY', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR',
#        'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KIR',
#        'KNA', 'KOR', 'KSV', 'KWT', 'LAC', 'LAO', 'LBN', 'LBR', 'LBY',
# ...

# %%
ClimateCh_df.columns
# Out:
# Index(['Country code', 'Country name',  'Series code',  'Series name',
#               'SCALE',     'Decimals',           1990,           1991,
#                  1992,           1993,           1994,           1995,
#                  1996,           1997,           1998,           1999,
#                  2000,           2001,           2002,           2003,
#                  2004,           2005,           2006,           2007,
#                  2008,           2009,           2010,           2011],
#       dtype='object')

# %%
ClimateCh_df[['Country code', 'Country name',  'Series code',  'Series name',
              'SCALE',     'Decimals',           1990,           1991,
                 1992,           1993,           1994,           1995,
                 1996,           1997,           1998,           1999,
                 2000,           2001,           2002,           2003,
                 2004,           2005,           2006,           2007,
                 2008,           2009,           2010,           2011
]].isna().sum()
# Out:
# Country code       0
# Country name       0
# Series code        0
# Series name        0
# SCALE              0
# Decimals           0
# 1990            3495
# 1991            3495
# 1992            3495
# 1993            3495
# 1994            3495
# 1995            3495
# 1996            3495
# 1997            3495
# 1998            3495
# 1999            3495
# 2000            3495
# 2001            3495
# 2002            3495
# 2003            3495
# 2004            3495
# 2005            3495
# 2006            3495
# 2007            3495
# 2008            3495
# 2009            3495
# 2010            3495
# 2011            1130
# dtype: int64

# %%
#ClimateCh_df[2009].loc[13100:13150]

# %%
X=ClimateCh_df['Decimals'].unique()
X[0:3]
# Out:
# array([1, 0, 'Text'], dtype=object)

# %%
#sns.lineplot(data=ClimateCh_df, x= ClimateCh_df.index, y='Decimals')

ClimateCh_df[['Decimals',           1990,           1991,                 1992,           1993,           1994,           1995,
                 1996,           1997,           1998,           1999,
                 2000,           2001,           2002,           2003,
                 2004,           2005,           2006,           2007,
                 2008,           2009,           2010,           2011
]].isna().sum()
# Out:
# Decimals       0
# 1990        3495
# 1991        3495
# 1992        3495
# 1993        3495
# 1994        3495
# 1995        3495
# 1996        3495
# 1997        3495
# 1998        3495
# 1999        3495
# 2000        3495
# 2001        3495
# 2002        3495
# 2003        3495
# 2004        3495
# 2005        3495
# 2006        3495
# 2007        3495
# 2008        3495
# 2009        3495
# 2010        3495
# 2011        1130
# dtype: int64

# %%
ClimateCh_df[['Decimals',           1990,           1991,                 1992,           1993,           1994,           1995,
                 1996,           1997,           1998,           1999,
                 2000,           2001,           2002,           2003,
                 2004,           2005,           2006,           2007,
                 2008,           2009,           2010,           2011
]].dropna()
# Out:
#       Decimals          1990             1991             1992  \
# 0            1      29.57481               ..               ..
# 1            1             0               ..               ..
# 2            1             0               ..               ..
# 3            1      0.208235               ..               ..
# 4            1      4.967875               ..               ..
# ...        ...           ...              ...              ...
# 13507        0   2497175.681     2693642.2632     2909756.3552
# 13508        0      18304000  18864881.576074  19446091.545173
# 13509        0  10120930.828    10569454.3904    11060046.8476
# 13510        0   3096860.882     3141668.2968     3183257.2304
# 13511        0    3036068.58      3175022.711      3310511.552
#
#                   1993             1994          1995             1996  \
# 0                   ..               ..            ..               ..
# ...

# %%
'''
if(
ClimateCh_df['SCALE'].unique()=='Text').any():
 print(ClimateCh_df.index)'''

X=len(ClimateCh_df['SCALE'])
X

'''for idx in len(ClimateCh_df['SCALE']):
  if ClimateCh_df['SCALE'].any()=='Text':
      print('index at ',idx)'''
# Out:
# "for idx in len(ClimateCh_df['SCALE']):\n  if ClimateCh_df['SCALE'].any()=='Text':\n      print('index at ',idx)"
