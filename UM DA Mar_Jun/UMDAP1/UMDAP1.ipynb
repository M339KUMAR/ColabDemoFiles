# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/UM%20DA%20Mar_Jun/UMDAP1/UMDAP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Streamlit example

# %%
# !pip -q install streamlit pyngrok
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 88.1 MB/s eta 0:00:00

# %%
'''2yIOvcZEaVwrAIECmtUofV0csZg_7XwsyKaB9TRqCGTQDfYvf'''
# Out:
# '2yIOvcZEaVwrAIECmtUofV0csZg_7XwsyKaB9TRqCGTQDfYvf'

# %%
#The below code works

from flask import Flask, render_template
from pyngrok import ngrok, conf
import os
import threading

from pyngrok import ngrok
import subprocess
import time

# write app file
with open("app.py", "w") as f:
    f.write("""
import streamlit as st
import pandas as pd

df = pd.read_excel('/content/sample_data/HHS_Unaccompanied_Alien_Children_Program.xlsx')
st.title("Hello from Colab via ngrok")
st.write("This works!")
st.dataframe(df)
st.write("Hello PRAVEENKUMAR MOPURU")
""")

ngrok.set_auth_token("2yIOvcZEaVwrAIECmtUofV0csZg_7XwsyKaB9TRqCGTQDfYvf")

# run streamlit
subprocess.Popen(["streamlit", "run", "app.py"])

time.sleep(5)

url = ngrok.connect(8501)
print(url)
# Out:
# NgrokTunnel: "https://2956-104-198-142-120.ngrok-free.app" -> "http://localhost:8501"

# %%
# !lsof -i:8501
# Out:
# COMMAND     PID USER   FD   TYPE DEVICE SIZE/OFF NODE NAME
# streamlit  3580 root   13u  IPv4 105401      0t0  TCP *:8501 (LISTEN)
# streamlit  3580 root   14u  IPv6 105402      0t0  TCP *:8501 (LISTEN)
# streamlit  3580 root   15u  IPv6 412234      0t0  TCP localhost:8501->localhost:40620 (ESTABLISHED)
# streamlit  3580 root   16u  IPv6 413094      0t0  TCP localhost:8501->localhost:38522 (ESTABLISHED)
# ngrok     12747 root    7u  IPv6 413072      0t0  TCP localhost:40620->localhost:8501 (ESTABLISHED)
# ngrok     12747 root    9u  IPv6 412268      0t0  TCP localhost:38522->localhost:8501 (ESTABLISHED)

# %%
#!kill -9 4259
# !kill -9 12747

# %%
from flask import Flask, render_template
from pyngrok import ngrok, conf
import os
import threading

# Create Flask app
app = Flask(__name__)

@app.route('/')
def home():
    return render_template("index.html")   #'Hello World!🙂👍😊123 This is running from Google Colab'

def run_app():
    app.run(host="0.0.0.0", port=5000)

conf.get_default().auth_token = "2yIOvcZEaVwrAIECmtUofV0csZg_7XwsyKaB9TRqCGTQDfYvf"

import threading
thread = threading.Thread(target=run_app)
thread.start()

public_url = ngrok.connect(5000)
print(" * ngrok tunnel:", public_url)
