# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/UMMLP4/UM_MLIntern_P4(23jan26%203).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Animal Classification 15 classess

# %% [markdown]
# ###Animal Classification/Image Classification of animals.pdf

# %% [markdown]
# ####Classess::
# Bear, Bird, Cat, Cow, Deer, Dog, Dolphin, Elephant, Giraffe, Horse, Kangaroo, Lion, Panda, Tiger, Zebra

# %% [markdown]
# ###Importing The Library

# %%
import pandas as pd
import zipfile
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ###Extracting the Dataset

# %%
input_path='/content/sample_data/animal_classification.zip'
output_path='/content/Animals'

# %%
with zipfile.ZipFile(input_path, 'r') as zf:
     zf.extractall(output_path)

# %% [markdown]
# ###Checking the images shape and size and displaying them

# %% [markdown]
# ####'/content/Animals/Animal Classification/dataset/Bear/Bear_10.jpg'

# %%
import os
import random
from PIL import Image
import matplotlib.image as mpimg

# %%
# %matplotlib inline
# %matplotlib notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#Working
# Path to the directory containing your 15 folders
base_path = '/content/Animals/Animal Classification/dataset'
#'/content/your_extracted_folder_path'

# Get list of all subdirectories (folders)
folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]
#print(folders)

# Set up the grid for display (e.g., 3 rows x 5 columns for 15 folders)
plt.figure(figsize=(20, 12))

for i, folder_name in enumerate(folders):
    folder_path = os.path.join(base_path, folder_name)
    #print("FOLDER_PATH")
    #print(folder_path)

    # List all image files in the folder (filtering for common extensions)
    images = [img for img in os.listdir(folder_path) if img.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]
    print('\n', images)

    test_folder = os.listdir(base_path)[0]
    #print(test_folder)

    test_path = os.path.join(base_path, test_folder)
    #print(os.listdir(test_path)[:5])

    if images:
        # Randomly select one image
        random_image = random.choice(images)
        img_path = os.path.join(folder_path, random_image)

        # Open and display the image in a subplot
        #img = mpimg.imread(img_path)
        plt.subplot(3, 5, i + 1)
        #plt.imshow(img)
        img=Image.open(img_path)
        display(img)
        plt.title(folder_name)
        plt.axis('off')
        #plt.show()
    else:
        print(f"No Images found on {folder_name}")

plt.tight_layout()
plt.show()
# Out:
#  ['Panda_4_3.jpg', 'Panda_26.jpeg', 'Panda_20_3.jpg', 'Panda_6_1.jpg', 'Panda_5_1.jpg', 'Panda_1.jpeg', 'Panda_6_2.jpg', 'Panda_9_2.jpg', 'Panda_5_2.jpg', 'Panda_24_3.jpg', 'Panda_28_1.jpg', 'Panda_29_3.jpg', 'Panda_29_4.jpg', 'Panda_25_1.jpg', 'Panda_6_3.jpg', 'Panda_15_3.jpg', 'Panda_27_1.jpg', 'Panda_19_3.jpg', 'Panda_15.jpg', 'Panda_30_4.jpg', 'Panda_13_1.jpg', 'Panda_16_3.jpg', 'Panda_7_1.jpg', 'Panda_27_2.jpg', 'Panda_3_3.jpg', 'Panda_14.jpg', 'Panda_21_1.jpg', 'Panda_30_2.jpg', 'Panda_22.jpeg', 'Panda_11_2.jpg', 'Panda_25.jpeg', 'Panda_20_1.jpg', 'Panda_24_2.jpg', 'Panda_16_2.jpg', 'Panda_18.jpeg', 'Panda_2_2.jpg', 'Panda_19_1.jpg', 'Panda_8_1.jpg', 'Panda_9_1.jpg', 'Panda_5.jpeg', 'Panda_15_2.jpg', 'Panda_10.jpeg', 'Panda_9_4.jpg', 'Panda_29.jpeg', 'Panda_26_2.jpg', 'Panda_11_4.jpg', 'Panda_18_2.jpg', 'Panda_6_4.jpg', 'Panda_8.jpg', 'Panda_3_1.jpg', 'Panda_23.jpeg', 'Panda_16.jpeg', 'Panda_24.jpeg', 'Panda_23_1.jpg', 'Panda_2_3.jpg', 'Panda_16_1.jpg', 'Panda_3_2.jpg', 'Panda_
# ...

# %%
import os, random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

base_path = '/content/Animals/Animal Classification/dataset'
folders = os.listdir(base_path)

print("Folders:", folders)

plt.figure(figsize=(15,10))

for i in range(min(9, len(folders))):
    folder = folders[i]
    path = os.path.join(base_path, folder)
    images = os.listdir(path)

    img_path = os.path.join(path, random.choice(images))
    img = mpimg.imread(img_path)

    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title(folder)
    plt.axis("off")

plt.show()
# Out:
# Folders: ['Panda', 'Elephant', 'Lion', 'Zebra', 'Deer', 'Horse', 'Bear', 'Bird', 'Tiger', 'Dolphin', 'Cow', 'Cat', 'Giraffe', 'Kangaroo', 'Dog']
# <div id='54f9fc52-e449-4720-b14e-e32a53abce08'></div>

# %%
img_path='/content/Animals/Animal Classification/dataset/Bear/Bear_10.jpg'
img = mpimg.imread(img_path)

plt.figure(figsize=(15,10))
plt.imshow(img)
plt.title(folder)
plt.axis("off")
plt.show()
# Out:
# <div id='6ff35de1-a311-4b99-9cea-d35fd6f58ef6'></div>

# %%
from PIL import Image
import matplotlib.pyplot as plt
import os, random

plt.figure(figsize=(20,12))

for i, folder in enumerate(folders):
    folder_path = os.path.join(base_path, folder)
    images = os.listdir(folder_path)

    img_path='/content/Animals/Animal Classification/dataset/Bear/Bear_10.jpg'
    #img = mpimg.imread(img_path)
    #img_path=
    #img_path = os.path.join(folder_path, random.choice(images))
    img = Image.open(img_path).convert("RGB")
    print(img)


    plt.subplot(3,5,i+1)
    plt.imshow(img)
    plt.title(folder)
    plt.axis("off")

plt.show()
# Out:
# <div id='c4038b63-30dd-42ec-ad4a-2cd694f62bd5'></div>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3DF2FE30>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3D5CD070>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BEE4800>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BEE69F0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BF10CB0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BD654F0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BD95130>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BD3DE50>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3CD11550>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BD3D130>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BDE9EE0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BC7C2C0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BC9C1A0>
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7C4F3BC9D8E0>
# ...

# %% [markdown]
# ###Counting Number of Files In each folder

# %%
def count_files_os(folder_path):
    """Counts the number of files in a given folder using os.listdir."""

    count = 0

    # List all entries in the directory
    for file in os.listdir(folder_path):

        # Construct the full path
        full_path = os.path.join(folder_path, file)

        # Check if the entry is a file (and not a sub-directory or symlink)
        if os.path.isfile(full_path):
            count += 1

    return count

# Example Usage:
# Replace 'your/folder/path' with the actual path to your folder
folder_to_check = '/content/Animals/Animal Classification/dataset/Bear'

file_count = count_files_os(folder_to_check)
#print(f"Total files count ::'{folder_to_check}': {file_count}")
print(f"Total files count ::: {file_count}")
# Out:
# Total files count ::: 125

# %%
Folders= ['Panda', 'Elephant', 'Lion', 'Zebra', 'Deer', 'Horse', 'Bear', 'Bird', 'Tiger', 'Dolphin', 'Cow', 'Cat', 'Giraffe', 'Kangaroo', 'Dog']

for i in Folders:
    folder_to_check = '/content/Animals/Animal Classification/dataset/'+i
    file_count = count_files_os(folder_to_check)
    print('----'*10)
    print(f"File Count in {folder_to_check}:: {file_count}")
# Out:
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Panda:: 135
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Elephant:: 133
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Lion:: 131
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Zebra:: 137
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Deer:: 127
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Horse:: 130
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Bear:: 125
# ----------------------------------------
# File Count in /content/Animals/Animal Classification/dataset/Bird:: 137
# ----------------------------------------
# ...

# %%
print(135+133+131+137+127+130+125+137+129+129+131+123+129+126+122)
# Out:
# 1944

# %%
print(1957-1944)
# Out:
# 13

# %% [markdown]
# ###Method 1

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

path='/content/Animals/Animal Classification/dataset/Bear/Bear_10.jpg'
img = Image.open(path)
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ###Method 2

# %%
from PIL import Image
from IPython.display import display

img = Image.open(path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>
