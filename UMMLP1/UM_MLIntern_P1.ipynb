# %% [markdown]
# <a href="https://colab.research.google.com/github/M339KUMAR/ColabDemoFiles/blob/main/UMMLP1/UM_MLIntern_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Project 1 :: Vehicle Price Prediction

# %% [markdown]
# ###Step 1: Importing The Lib's

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Loding the Dataset

# %%
file_path='/content/sample_data/Veh Prices Dataset.csv'
df_vpp= pd.read_csv(file_path)

# %%
df_vpp.shape
# Out:
# (1002, 17)

# %%
df_vpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   year            1002 non-null   int64
#  5   price           979 non-null    float64
#  6   engine          1000 non-null   object
#  7   cylinders       897 non-null    float64
#  8   fuel            995 non-null    object
#  9   mileage         968 non-null    float64
#  10  transmission    1000 non-null   object
#  11  trim            1001 non-null   object
#  12  body            999 non-null    object
#  13  doors           995 non-null    float64
#  14  exterior_color  997 non-null    object
#  15  interior_color  964 non-null    object
#  16  drivetrain      1002 non-null   object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 133.2+ KB

# %%
df_vpp.isnull().sum()
# Out:
# name                0
# description        56
# make                0
# model               0
# year                0
# price              23
# engine              2
# cylinders         105
# fuel                7
# mileage            34
# transmission        2
# trim                1
# body                3
# doors               7
# exterior_color      5
# interior_color     38
# drivetrain          0
# dtype: int64

# %%
df_vpp.describe(include=['int','float'])
# Out:
#               year          price   cylinders      mileage       doors
# count  1002.000000     979.000000  897.000000   968.000000  995.000000
# mean   2023.916168   50202.985700    4.975474    69.033058    3.943719
# std       0.298109   18700.392062    1.392526   507.435745    0.274409
# min    2023.000000       0.000000    0.000000     0.000000    2.000000
# 25%    2024.000000   36600.000000    4.000000     4.000000    4.000000
# 50%    2024.000000   47165.000000    4.000000     8.000000    4.000000
# 75%    2024.000000   58919.500000    6.000000    13.000000    4.000000
# max    2025.000000  195895.000000    8.000000  9711.000000    5.000000

# %%
df_vpp.describe(include='object')
# Out:
#                               name                        description  make  \
# count                         1002                                946  1002
# unique                         358                                761    28
# top     2023 Dodge Durango Pursuit  \n      \n        .\n      \n      Jeep
# freq                            33                                 13   194
#
#          model              engine      fuel       transmission     trim body  \
# count     1002                1000       995               1000     1001  999
# unique     153                 100         7                 38      197    8
# top     Hornet  16V GDI DOHC Turbo  Gasoline  8-Speed Automatic  Limited  SUV
# freq        65                 130       664                325       69  704
#
#                 exterior_color interior_color       drivetrain
# count                      997            964             1002
# unique                     263             91                4
# top     Bright White Clearcoat          Black  All-wheel Drive
# freq                        81            510              461

# %%
df_vpp.sample(1).T
# Out:
#                                                                 7
# name                            2024 Ford F-350 Lariat Super Duty
# description     \n      \n        Engine: 6.7L High Output Pow...
# make                                                         Ford
# model                                                       F-350
# year                                                         2024
# price                                                     89978.0
# engine                                   32V DDI OHV Turbo Diesel
# cylinders                                                     8.0
# fuel                                                       Diesel
# mileage                                                      15.0
# transmission                                   10-Speed Automatic
# trim                                            Lariat Super Duty
# body                                                 Pickup Truck
# doors                                                         4.0
# exterior_color                           Carbonized Gray Metallic
# interior_color                                         Black Onyx
# drivetrain                                       Four-wheel Drive

# %%
df_vpp[673:674]
# Out:
#                                name  \
# 673  2024 Honda CR-V Hybrid Sport-L
#
#                                            description   make        model  \
# 673  \n      \n        This 2024 Honda CR-V Hybrid ...  Honda  CR-V Hybrid
#
#      year    price               engine  cylinders    fuel  mileage  \
# 673  2024  37505.0  16V GDI DOHC Hybrid        4.0  Hybrid      0.0
#
#       transmission     trim body  doors        exterior_color interior_color  \
# 673  Automatic CVT  Sport-L  SUV    4.0  Platinum White Pearl            NaN
#
#             drivetrain
# 673  Front-wheel Drive

# %%
dfname=list(set(df_vpp['name'].values.tolist()))
dfname
# Out:
# ["2024 RAM 3500 Tradesman Crew Cab 4x4 8' Box",
#  '2023 Chrysler 300 Touring',
#  '2023 Nissan Titan SV',
#  '2024 Nissan Murano SL',
#  '2024 Hyundai Kona Limited',
#  '2024 BMW M235 Gran Coupe i xDrive',
#  '2024 Hyundai Santa Fe Calligraphy',
#  '2024 Chevrolet Silverado 1500 LT',
#  '2024 Kia Sorento LX',
#  '2024 Ford Transit-150 Base',
#  '2024 Ford Transit-250 Base',
#  '2024 Chevrolet Equinox LS',
#  '2024 Buick Envista Sport Touring',
#  '2024 BMW i4 Gran Coupe eDrive40',
#  '2024 Chevrolet Silverado 2500 LT',
#  '2024 GMC Terrain Denali',
#  '2024 Hyundai IONIQ 5 SEL',
#  '2024 Dodge Hornet R/T EAWD',
#  '2024 Hyundai Tucson Hybrid N Line',
#  '2024 Jeep Wagoneer Series II',
#  '2024 BMW i5 M60',
#  '2024 Subaru Outback Wilderness',
#  '2024 Audi Q8 e-tron Premium',
#  '2024 GMC Terrain SLE',
#  '2024 Buick Enclave Premium',
#  '2023 Kia Sorento EX',
#  '2024 Ford Explorer Timberline',
#  "2024 RAM 2500 Tradesman Regular Cab 4x4 8' Box",
#  '2024 GMC Sierra 2500 Pro',
#  '2024 Nissan Kicks SV',
#  '2024 Chrysler Voyager LX',
#  '2024 Jeep Compass Trailhawk',
#  '2024 Dodge Hornet GT Plus',
#  '2024 Nissan Murano SV Intelligent AWD',
#  '2024 Subaru Impreza RS',
#  '2024 BMW i4 Gran Coupe xDrive40',
#  '2024 Kia Telluride SX X-Pro',
#  '2024 GMC Sierra 2500 Denali',
#  '2024 Kia Soul S',
#  '2024 Volkswagen Taos 1.5T SE',
#  '2024 Hyundai Tucson Hybrid SEL Convenience',
#  '2024 Kia Forte LXS',
#  '2024 Ford Maverick Lariat',
#  '2024 Nissan Rogue SV',
#  '2024 Nissan Altima 2.5 SV',
#  '2024 Hyundai Santa Cruz 2.5L SE',
#  '2024 Nissan Murano Platinum',
#  '2024 RAM 3500 Tradesman/SLT/Laramie/Limited',
#  '2024 Kia Sportage S',
#  '2024 Mercedes-Benz GLS 450 4MATIC',
#  '2023 Ford Mustang Mach-E Premium',
#  '2024 GMC Sierra 1500 SLT',
#  '2024 Nissan Murano SV',
#  '2024 Land Rover Discovery Sport Dynamic SE',
#  "2024 RAM 3500 Laramie Crew Cab 4x4 8' Box",
#  '2023 Chrysler 300 Touring L',
#  '2024 Nissan Frontier SV',
#  '2024 Toyota Corolla Cross LE',
#  '2024 Chevrolet Blazer EV RS',
#  '2024 Acura ZDX A-SPEC',
#  '2024 Jeep Grand Cherokee 4xe Anniversary Edition',
#  '2024 Audi A3 Premium',
#  '2024 BMW i7 eDrive50',
#  '2024 Nissan Kicks S',
#  '2024 Chevrolet Equinox FWD RS',
#  '2024 Volvo XC90 Recharge Plug-In Hybrid T8 Plus Bright Theme 7 Passenger',
#  '2024 Kia Niro SX Touring',
#  '2024 Volkswagen Taos 1.5T SEL',
#  '2023 Dodge Charger SXT',
#  '2024 Audi Q8 e-tron S line Premium',
#  '2024 Mercedes-Benz Sprinter 2500 Standard Roof',
#  '2024 Chevrolet Silverado 2500 WT',
#  '2024 Volkswagen ID.4 Standard',
#  '2024 Jeep Grand Cherokee 4xe Base',
#  '2024 Lexus RX 500h F SPORT PERFORMANCE',
#  '2024 Ford Escape S',
#  '2024 Ford Edge SE',
#  '2024 Chevrolet Silverado 1500 ZR2',
#  '2024 Hyundai IONIQ 5 Limited',
#  '2024 Volkswagen Atlas Cross Sport 2.0T SEL R-Line',
#  '2024 Ford F-350 XL',
#  '2024 Jeep Wrangler Sport S',
#  '2024 Buick Encore GX Avenir',
#  '2023 INFINITI QX55 SENSORY',
#  '2024 Kia Sorento Hybrid EX',
#  '2023 Buick Envision Essence',
#  '2024 Volkswagen Atlas 2.0T Peak Edition SE w/Technology',
#  '2024 Mercedes-Benz AMG GLE 53 Base',
#  '2024 Toyota Tundra Hybrid Limited',
#  '2024 Ford Expedition XLT',
#  '2024 Honda Passport TrailSport',
#  '2024 GMC Sierra 3500 Denali',
#  '2024 RAM 2500 Laramie',
#  '2024 Volkswagen Jetta 1.4T SEL',
#  '2024 Mazda CX-90 PHEV Preferred',
#  '2024 Kia Niro EX',
#  '2024 Hyundai Tucson Hybrid Limited',
#  '2023 Ford F-150 XLT',
#  '2024 RAM ProMaster 2500 High Roof',
#  '2024 Chevrolet Silverado 1500 LT Trail Boss',
#  '2024 Nissan Kicks SR',
#  '2023 Hyundai IONIQ 6 SEL',
#  '2023 Jeep Wrangler 4xe Sahara',
#  '2024 Dodge Hornet Hornet R/T Eawd',
#  '2024 Kia Sportage SX-Prestige',
#  '2024 Toyota Corolla LE',
#  '2024 BMW 530 i',
#  '2024 Mercedes-Benz EQS 450 Base 4MATIC',
#  '2024 INFINITI QX50 SPORT',
#  '2024 Nissan Versa 1.6 SV',
#  '2024 Chevrolet Silverado 1500 RST',
#  '2024 Mercedes-Benz AMG C 43 Base 4MATIC',
#  '2024 Hyundai Santa Cruz 2.5L SEL',
#  '2024 Ford Expedition Platinum',
#  '2024 Ford Escape ST-Line',
#  '2024 GMC Sierra 3500 SLT',
#  '2023 Chrysler Pacifica Touring L',
#  '2024 Hyundai Palisade SEL',
#  '2024 Jeep Wrangler 4xe Rubicon X',
#  '2024 Dodge Durango GT',
#  '2024 Hyundai Kona SEL',
#  '2024 GMC Terrain AT4',
#  '2024 Jeep Wrangler 4xe Rubicon',
#  '2024 Ford Mustang Mach-E Select',
#  '2024 Honda CR-V Hybrid Sport-L',
#  '2024 Kia EV9 Light Long Range',
#  '2023 Ford Transit-350 ',
#  '2024 Ford F-350 Lariat Super Duty',
#  '2024 Jeep Grand Cherokee L Altitude',
#  '2024 Kia Sportage X-Pro Prestige',
#  '2024 Volkswagen Jetta 1.5T SE',
#  '2024 Kia Seltos EX',
#  '2024 Chevrolet Silverado 1500 Custom Trail Boss',
#  "2024 RAM 3500 Laramie Mega Cab 4x4 6'4' Box",
#  '2024 Cadillac XT5 Luxury',
#  '2024 Jeep Wagoneer Base',
#  '2024 Volkswagen Atlas Cross Sport 2.0T SEL',
#  '2024 Cadillac LYRIQ Sport w/1SJ',
#  '2024 GMC Terrain SLT',
#  '2024 Nissan Titan SV',
#  '2024 RAM 2500 Power Wagon',
#  '2024 Mazda CX-90 3.3 Turbo S Premium',
#  '2024 Audi Q5 e 55 Premium Plus',
#  '2023 Mazda MX-5 Miata RF Grand Touring',
#  '2024 Chevrolet Trax LT',
#  '2023 Jeep Grand Wagoneer Series II',
#  '2024 Chrysler Pacifica Touring-L',
#  '2024 Subaru Legacy Premium',
#  '2024 Hyundai IONIQ 6 SE',
#  '2024 Nissan Sentra SV',
#  '2024 BMW X3 sDrive30i',
#  '2024 Ford Transit-250 148 WB Medium Roof Cargo',
#  '2024 Ford Edge Titanium',
#  '2024 GMC Sierra 2500 Denali Ultimate',
#  '2024 Ford Explorer XLT',
#  '2023 Jeep Compass Latitude',
#  '2024 Jeep Wagoneer L Base',
#  '2024 Hyundai Santa Cruz 2.5T XRT',
#  '2024 Jeep Grand Cherokee 4xe Overland',
#  '2023 Genesis Electrified G80 Base',
#  '2024 Hyundai IONIQ 6 SEL',
#  '2024 Toyota Tundra Hybrid 1794 Edition',
#  '2024 Jeep Grand Cherokee 4xe Summit',
#  '2024 Mercedes-Benz GLE 350 Base 4MATIC',
#  '2024 Land Rover Defender P400 X-Dynamic SE',
#  '2024 Kia EV6 Wind',
#  '2024 Hyundai IONIQ 5 Disney100 Platinum Edition',
#  '2024 Nissan Pathfinder SL 4WD',
#  '2024 Dodge Durango R/T',
#  '2024 RAM 2500 Big Horn',
#  '2024 Honda Prologue TOURING',
#  '2024 Jeep Grand Cherokee Altitude',
#  '2024 Mazda CX-90 PHEV Premium Plus',
#  '2024 Hyundai Elantra HEV Blue',
#  '2024 Kia Sportage SX',
#  '2024 BMW X7 M60i',
#  '2024 Mercedes-Benz Sprinter 2500 Crew 144 WB',
#  '2024 Jeep Grand Cherokee L Overland',
#  '2024 Audi RS e-tron GT quattro',
#  '2024 GMC Yukon XL Denali',
#  '2024 Dodge Hornet Hornet Gt Awd',
#  '2024 Ford Mustang Mach-E Premium',
#  '2024 BMW i7 M70',
#  '2024 Mercedes-Benz Sprinter 2500 144 WB Standard Roof Crew',
#  '2024 Mercedes-Benz Sprinter 2500 144 WB Standard Roof Passenger',
#  '2024 RAM 3500 Tradesman',
#  '2024 Subaru Impreza Sport',
#  '2024 Cadillac LYRIQ Luxury',
#  '2024 Cadillac XT6 Luxury FWD',
#  '2024 Jeep Grand Cherokee 4xe Trailhawk',
#  '2024 Volkswagen Jetta 1.5T SEL',
#  '2023 Buick Envision Preferred',
#  '2024 Nissan Versa S',
#  '2025 Mazda CX-70 3.3 Turbo S Premium',
#  '2024 Acura MDX Advance',
#  '2024 Mazda CX-90 PHEV Premium',
#  '2024 Hyundai IONIQ 5 SE Standard Range',
#  '2024 Ford Bronco Sport Free Wheeling',
#  '2024 Jeep Wrangler 4xe Sport S',
#  '2024 Cadillac LYRIQ Sport w/1SF',
#  '2023 Jeep Wagoneer L Base',
#  '2024 Dodge Hornet R/T Plus EAWD',
#  '2024 Dodge Hornet R/T',
#  '2024 BMW i5 eDrive40',
#  '2023 Jeep Grand Cherokee Laredo',
#  '2024 Hyundai IONIQ 5 SE',
#  '2024 Mercedes-Benz Sprinter 3500 170 WB High Roof Extended Cargo',
#  '2024 Mazda CX-90 3.3 Turbo Premium Plus',
#  '2024 INFINITI QX50 LUXE',
#  '2025 Honda CR-V EX-L',
#  '2024 Ford Bronco Sport Big Bend',
#  '2024 Hyundai Santa Cruz 2.5T NIGHT',
#  '2024 Kia EV6 GT',
#  '2023 Dodge Durango Pursuit',
#  '2024 Ford Escape Platinum',
#  '2024 Ford Transit-350 Base',
#  '2024 Ford Edge ST-Line',
#  '2024 Jeep Grand Cherokee Laredo',
#  '2023 Mercedes-Benz Sprinter 2500 High Roof',
#  '2024 Jeep Compass Latitude',
#  '2024 Jeep Wagoneer L Series II Carbide 4x4',
#  '2024 Chevrolet Equinox RS',
#  '2024 Dodge Hornet Hornet R/T Plus Eawd',
#  '2024 RAM ProMaster 1500 Low Roof',
#  '2024 Buick Envista Preferred',
#  '2024 Honda CR-V Hybrid Sport Touring',
#  '2024 Mercedes-Benz Sprinter 2500 High Roof',
#  '2024 Hyundai Santa Fe XRT',
#  '2024 Nissan Versa 1.6 SR',
#  '2025 Ford Explorer Platinum',
#  '2023 Dodge Charger Scat Pack',
#  '2024 Jeep Wrangler 4xe Sport',
#  '2024 Land Rover Range Rover Evoque Dynamic SE',
#  '2024 Jeep Wrangler 4-Door Sahara 4x4',
#  '2024 Chevrolet Equinox 1LT',
#  '2024 Kia Sportage X-Line',
#  '2024 Honda CR-V EX-L',
#  '2024 BMW i4 Gran Coupe M50',
#  '2024 Honda HR-V LX',
#  '2024 Hyundai Tucson Hybrid Blue',
#  '2024 Nissan Rogue SL',
#  '2024 Ford Ranger XL',
#  '2024 Mercedes-Benz GLE 450 4MATIC',
#  '2024 Chevrolet Silverado 1500 Custom',
#  '2024 Jeep Grand Cherokee L Laredo',
#  '2023 Ford Transit-350 Base',
#  '2024 Cadillac XT5 Premium Luxury',
#  '2024 Audi A5 Sportback S line Premium',
#  '2023 Jeep Compass Sport',
#  '2024 Jeep Grand Wagoneer Series III',
#  '2025 BMW X7 xDrive40i',
#  '2024 Jeep Gladiator Sport',
#  '2023 RAM ProMaster 2500 High Roof',
#  '2024 Ford Expedition Limited',
#  '2024 Hyundai Santa Cruz 2.5T Limited',
#  '2024 Chevrolet Trailblazer RS',
#  '2024 Honda Odyssey Elite',
#  '2024 Toyota RAV4 Prime XSE',
#  '2024 Lincoln Corsair Reserve',
#  '2024 Subaru Solterra Premium',
#  '2023 Jeep Wagoneer L Series III',
#  '2024 Dodge Durango Pursuit',
#  '2024 Jeep Wagoneer Series III',
#  '2024 Hyundai Tucson SEL',
#  '2025 Honda CR-V Hybrid Sport Touring',
#  '2024 RAM ProMaster 3500 High Roof',
#  '2024 Kia Sportage EX',
#  '2024 Jeep Grand Cherokee Summit',
#  '2024 Hyundai Kona N Line',
#  '2024 Subaru Outback Premium',
#  '2024 Hyundai Elantra HEV Limited',
#  '2024 Hyundai Sonata Hybrid Limited',
#  '2024 Kia Niro Touring',
#  '2024 Buick Envista Avenir',
#  '2024 Hyundai Santa Fe SE 2.4',
#  '2024 Hyundai Tucson Limited',
#  '2024 Genesis Electrified GV70 Advanced',
#  '2024 Jeep Wagoneer L Series II',
#  '2024 Jeep Wrangler Rubicon',
#  '2023 Jeep Grand Cherokee 4xe Trailhawk',
#  '2024 RAM 3500 Big Horn',
#  '2024 Honda CR-V Hybrid Sport',
#  '2024 Honda Odyssey Touring',
#  '2024 Lincoln Nautilus Reserve',
#  '2023 Jeep Gladiator Rubicon',
#  '2024 Toyota Tundra Hybrid Platinum',
#  '2024 Ford Expedition King Ranch',
#  '2023 Ford Transit Connect XLT',
#  '2024 Ford Escape Active',
#  '2024 Chrysler Pacifica Limited',
#  '2024 RAM 2500 Longhorn',
#  '2024 Jeep Grand Cherokee L Limited',
#  '2024 Volkswagen Taos 1.5T S',
#  '2024 Audi SQ5 Premium Plus',
#  '2024 Ford Bronco Sport Outer Banks',
#  '2024 Audi SQ8 e-tron Premium Plus',
#  '2024 Ford Maverick XLT',
#  '2024 Dodge Hornet GT',
#  '2023 Ford Mustang Mach-E GT',
#  '2024 Jeep Grand Cherokee Limited',
#  '2024 Dodge Hornet GT AWD',
#  '2024 Volkswagen Jetta 1.4T S',
#  '2024 RAM 2500 Tradesman',
#  '2024 Jeep Compass Limited',
#  '2023 RAM 3500 Tradesman',
#  '2024 Jeep Compass Sport',
#  '2024 Jaguar I-PACE EV400 R-Dynamic HSE',
#  '2024 Kia Seltos SX',
#  '2024 Jeep Wrangler 4xe Sahara',
#  '2024 RAM ProMaster 3500 Base',
#  '2024 Dodge Hornet GT Plus AWD',
#  '2024 RAM 2500 Tradesman 4x4 Crew Cab 8 Box',
#  '2024 Volkswagen Jetta 1.5T S',
#  '2024 Jeep Compass Latitude Lux',
#  '2024 Subaru Outback Limited',
#  '2024 Ford Edge SEL',
#  '2024 BMW X7 xDrive40i',
#  '2024 Hyundai Sonata Hybrid SEL',
#  '2024 Ford Transit-350 148 WB Medium Roof Cargo',
#  '2023 Jeep Compass Trailhawk',
#  '2024 Mazda CX-90 PHEV Base',
#  '2024 Volkswagen Jetta 1.4T SE',
#  '2024 Audi Q5 e 55 Prestige',
#  '2024 Ford Escape ST-Line Elite',
#  '2024 Ford Bronco Wildtrak',
#  '2024 Mercedes-Benz GLA 250 Base 4MATIC',
#  '2024 GMC Sierra 1500 Denali Ultimate',
#  '2024 Chrysler Pacifica Hybrid Select',
#  '2023 Hyundai IONIQ 6 SE',
#  '2023 Kia Sorento SX',
#  '2024 Acura MDX Technology',
#  '2024 RAM 3500 Laramie',
#  '2024 Kia Sportage Hybrid EX',
#  '2024 Jeep Grand Cherokee 4xe 4x4',
#  '2024 Chevrolet Equinox EV RS',
#  '2025 Chevrolet Trax ACTIV',
#  '2023 Volvo C40 Recharge Pure Electric Twin Ultimate',
#  '2024 Acura MDX Base',
#  '2023 Dodge Durango R/T',
#  '2024 Honda Odyssey EX-L',
#  '2024 GMC Savana 2500 Work Van',
#  '2024 Mercedes-Benz Sprinter 3500 High Roof',
#  '2024 Audi A5 Sportback S line Premium Plus',
#  '2024 Mercedes-Benz EQE 350+ Base',
#  '2024 BMW 740 i',
#  '2024 Ford F-150 STX',
#  '2024 Ford Expedition Timberline',
#  '2024 Audi Q5 e Premium 55 TFSI e S line quattro S tronic',
#  '2024 Hyundai Sonata SEL',
#  '2024 Volvo S60 Recharge Plug-In Hybrid T8 Plus Dark Theme',
#  '2024 Chevrolet Blazer EV 2LT',
#  '2024 Chevrolet Silverado 1500 WT',
#  '2023 RAM ProMaster 3500 High Roof',
#  '2024 GMC Yukon XL SLT',
#  '2024 Chevrolet Blazer 3LT',
#  '2024 Dodge Hornet R/T Plus',
#  '2024 Kia Seltos S',
#  '2024 Hyundai Kona SE']

# %%
df_vpp['name']=df_vpp['name'].astype('str')
df_vpp['first_4_char']=df_vpp['name'].str[:4]
df_vpp['remain_char']=df_vpp['name'].str[4:]

# %%
df_vpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   year            1002 non-null   int64
#  5   price           979 non-null    float64
#  6   engine          1000 non-null   object
#  7   cylinders       897 non-null    float64
#  8   fuel            995 non-null    object
#  9   mileage         968 non-null    float64
#  10  transmission    1000 non-null   object
#  11  trim            1001 non-null   object
#  12  body            999 non-null    object
#  13  doors           995 non-null    float64
#  14  exterior_color  997 non-null    object
#  15  interior_color  964 non-null    object
#  16  drivetrain      1002 non-null   object
#  17  first_4_char    1002 non-null   object
#  18  remain_char     1002 non-null   object
# dtypes: float64(4), int64(1), object(14)
# memory usage: 148.9+ KB

# %%
df_vpp[['first_4_char','year']].sample(10).T
# Out:
#                879   569   389   353   297   664   787   320   469   525
# first_4_char  2024  2024  2024  2024  2023  2024  2024  2024  2023  2023
# year          2024  2024  2024  2024  2023  2024  2024  2024  2023  2023

# %%
df_vpp[['first_4_char']].value_counts()
# Out:
# first_4_char
# 2024            906
# 2023             90
# 2025              6
# Name: count, dtype: int64

# %% [markdown]
# ####The following Columns have Null values in them

# %%
Null_val={'description':56,
'price':23,
'engine':2,
'cylinders':105,
'fuel':7,
'mileage':34,
'transmission':2,
'trim':1,
'body':3,
'doors':7,
'exterior_color':5,
'interior_color':38}

# %% [markdown]
# ###Step 3: Handling Null Values

# %%
df_vpp[df_vpp['description'].isnull()].index.tolist()
# Out:
# [2,
#  8,
#  23,
#  39,
#  58,
#  81,
#  86,
#  89,
#  97,
#  113,
#  121,
#  137,
#  155,
#  216,
#  238,
#  269,
#  291,
#  310,
#  311,
#  313,
#  343,
#  357,
#  362,
#  367,
#  386,
#  387,
#  391,
#  397,
#  420,
#  437,
#  488,
#  520,
#  575,
#  580,
#  589,
#  596,
#  598,
#  638,
#  706,
#  759,
#  765,
#  785,
#  806,
#  807,
#  850,
#  863,
#  877,
#  886,
#  888,
#  898,
#  900,
#  963,
#  975,
#  977,
#  985,
#  987]

# %%
df_vpp[df_vpp['price'].isnull()].index.tolist()
# Out:
# [142,
#  248,
#  283,
#  328,
#  372,
#  417,
#  434,
#  443,
#  500,
#  506,
#  536,
#  541,
#  627,
#  678,
#  683,
#  704,
#  779,
#  809,
#  811,
#  859,
#  876,
#  937,
#  943]

# %%
df_vpp[df_vpp['engine'].isnull()].index.tolist()
# Out:
# [614, 803]

# %%
df_vpp[df_vpp['cylinders'].isnull()].index.tolist()
# Out:
# [14,
#  28,
#  33,
#  35,
#  49,
#  50,
#  53,
#  62,
#  68,
#  86,
#  100,
#  110,
#  116,
#  121,
#  128,
#  131,
#  142,
#  146,
#  180,
#  191,
#  192,
#  209,
#  210,
#  214,
#  218,
#  219,
#  223,
#  227,
#  239,
#  251,
#  252,
#  253,
#  255,
#  273,
#  287,
#  291,
#  293,
#  307,
#  315,
#  323,
#  328,
#  337,
#  340,
#  347,
#  372,
#  373,
#  384,
#  390,
#  392,
#  393,
#  409,
#  413,
#  419,
#  424,
#  436,
#  447,
#  479,
#  480,
#  481,
#  484,
#  489,
#  490,
#  494,
#  495,
#  499,
#  512,
#  514,
#  522,
#  531,
#  554,
#  555,
#  563,
#  567,
#  573,
#  582,
#  586,
#  590,
#  598,
#  604,
#  610,
#  613,
#  630,
#  632,
#  661,
#  681,
#  725,
#  726,
#  728,
#  737,
#  742,
#  743,
#  747,
#  752,
#  764,
#  767,
#  777,
#  813,
#  839,
#  866,
#  883,
#  884,
#  893,
#  941,
#  944,
#  978]

# %%
df_vpp[df_vpp['fuel'].isnull()].index.tolist()
# Out:
# [128, 219, 315, 489, 490, 610, 726]

# %%
df_vpp[df_vpp['mileage'].isnull()].index.tolist()
# Out:
# [27,
#  47,
#  63,
#  73,
#  84,
#  87,
#  93,
#  177,
#  217,
#  219,
#  225,
#  234,
#  261,
#  262,
#  365,
#  399,
#  461,
#  476,
#  489,
#  490,
#  503,
#  594,
#  596,
#  607,
#  628,
#  629,
#  801,
#  847,
#  879,
#  885,
#  906,
#  916,
#  922,
#  980]

# %%
df_vpp[df_vpp['transmission'].isnull()].index.tolist()
# Out:
# [725, 940]

# %%
df_vpp[df_vpp['trim'].isnull()].index.tolist()
# Out:
# [805]

# %%
df_vpp[df_vpp['body'].isnull()].index.tolist()
# Out:
# [164, 235, 687]

# %%
df_vpp[df_vpp['doors'].isnull()].index.tolist()
# Out:
# [124, 190, 215, 610, 614, 857, 893]

# %%
df_vpp[df_vpp['exterior_color'].isnull()].index.tolist()
# Out:
# [117, 137, 373, 608, 612]

# %%
df_vpp[df_vpp['interior_color'].isnull()].index.tolist()
# Out:
# [44,
#  48,
#  71,
#  77,
#  134,
#  137,
#  161,
#  169,
#  245,
#  286,
#  407,
#  414,
#  416,
#  443,
#  446,
#  452,
#  454,
#  466,
#  478,
#  480,
#  582,
#  608,
#  612,
#  673,
#  675,
#  708,
#  741,
#  771,
#  790,
#  812,
#  819,
#  824,
#  844,
#  853,
#  858,
#  940,
#  967,
#  971]

# %%
idx=df_vpp[df_vpp['engine'].str.contains('DOHC', na=False)].index
print(len(idx))#691
print(1002-691)
print(idx.tolist())
# Out:
# 691
# 311
# [0, 5, 6, 8, 9, 10, 12, 13, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 26, 27, 30, 31, 32, 34, 37, 38, 39, 41, 42, 43, 45, 47, 48, 51, 52, 55, 56, 57, 58, 59, 60, 61, 63, 64, 65, 66, 67, 69, 70, 72, 73, 74, 75, 76, 80, 82, 83, 85, 87, 88, 89, 91, 92, 93, 96, 99, 101, 102, 104, 105, 107, 108, 109, 111, 112, 113, 114, 115, 117, 118, 120, 123, 124, 125, 126, 127, 129, 130, 132, 133, 135, 136, 138, 139, 140, 141, 143, 144, 145, 147, 148, 149, 150, 151, 152, 154, 155, 156, 157, 158, 159, 160, 162, 163, 164, 165, 166, 167, 168, 170, 171, 174, 175, 176, 177, 178, 179, 181, 182, 183, 184, 185, 186, 187, 188, 190, 193, 194, 198, 199, 200, 202, 204, 206, 207, 211, 212, 213, 215, 216, 217, 220, 221, 222, 224, 225, 226, 228, 229, 230, 232, 233, 234, 235, 236, 237, 238, 243, 244, 250, 256, 257, 258, 260, 261, 262, 263, 265, 266, 267, 270, 274, 275, 276, 277, 278, 279, 280, 281, 283, 284, 285, 288, 294, 295, 298, 300, 301, 302, 304, 305, 306, 309, 310, 311, 312, 316, 318, 319, 320, 321, 322, 324, 325, 326, 327, 329, 330, 331, 332, 333, 335, 339, 341, 342, 343, 345, 346, 348, 349, 350, 351, 352, 353, 354, 355, 356, 358, 359, 360, 361, 362, 364, 365, 366, 367, 368, 369, 370, 371, 374, 375, 379, 380, 381, 382, 383, 385, 386, 387, 388, 389, 391, 394, 395, 396, 398, 399, 401, 402, 403, 404, 405, 406, 408, 410, 411, 412, 416, 418, 420, 423, 426, 427, 428, 429, 430, 431, 432, 434, 437, 438, 440, 441, 442, 443, 444, 445, 449, 450, 451, 452, 453, 454, 456, 457, 458, 459, 460, 461, 462, 463, 468, 470, 472, 473, 475, 476, 477, 486, 487, 488, 491, 492, 493, 496, 498, 500, 501, 502, 503, 504, 505, 506, 507, 508, 511, 515, 516, 517, 520, 521, 523, 524, 526, 527, 528, 529, 530, 533, 534, 535, 536, 537, 538, 539, 540, 542, 543, 544, 545, 546, 547, 549, 550, 552, 556, 557, 558, 559, 560, 561, 562, 565, 569, 570, 571, 572, 575, 576, 577, 578, 579, 580, 581, 583, 587, 591, 592, 593, 594, 595, 596, 597, 599, 600, 602, 603, 605, 606, 607, 608, 611, 612, 615, 616, 617, 618, 620, 622, 623, 624, 625, 626, 627, 628, 629, 631, 633, 634, 636, 637, 638, 640, 641, 642, 643, 644, 645, 646, 647, 648, 649, 650, 653, 654, 655, 657, 658, 659, 660, 662, 663, 664, 665, 667, 668, 669, 670, 671, 673, 674, 676, 678, 679, 680, 682, 683, 684, 686, 688, 689, 690, 691, 692, 693, 694, 696, 697, 698, 699, 702, 703, 704, 706, 707, 708, 709, 710, 711, 712, 718, 719, 723, 724, 729, 732, 733, 734, 735, 736, 738, 739, 740, 741, 748, 749, 751, 753, 754, 755, 756, 757, 758, 760, 761, 763, 765, 766, 768, 770, 771, 772, 773, 774, 775, 776, 778, 779, 780, 781, 782, 783, 785, 786, 787, 788, 790, 791, 792, 793, 795, 798, 799, 801, 802, 804, 805, 808, 810, 811, 814, 816, 817, 818, 819, 820, 821, 822, 823, 824, 825, 826, 827, 828, 829, 831, 834, 835, 836, 840, 841, 842, 843, 844, 845, 846, 847, 848, 849, 850, 851, 852, 853, 854, 855, 856, 858, 859, 860, 862, 863, 864, 867, 868, 870, 871, 872, 874, 875, 876, 877, 878, 880, 881, 882, 885, 886, 888, 889, 890, 891, 892, 895, 896, 897, 898, 900, 902, 903, 904, 905, 906, 907, 908, 909, 910, 911, 913, 915, 916, 917, 918, 919, 920, 922, 923, 924, 926, 927, 929, 930, 931, 932, 933, 934, 935, 936, 937, 938, 939, 940, 942, 943, 945, 946, 947, 949, 950, 951, 952, 953, 954, 956, 957, 958, 959, 960, 961, 963, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 993, 994, 995, 997, 998, 999, 1000]

# %% [markdown]
# ###Creating a Seperate copy of DataFrame

# %%
dfvpp_cpy=df_vpp.copy(deep=True)
dfvpp_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   year            1002 non-null   int64
#  5   price           979 non-null    float64
#  6   engine          1000 non-null   object
#  7   cylinders       897 non-null    float64
#  8   fuel            995 non-null    object
#  9   mileage         968 non-null    float64
#  10  transmission    1000 non-null   object
#  11  trim            1001 non-null   object
#  12  body            999 non-null    object
#  13  doors           995 non-null    float64
#  14  exterior_color  997 non-null    object
#  15  interior_color  964 non-null    object
#  16  drivetrain      1002 non-null   object
#  17  first_4_char    1002 non-null   object
#  18  remain_char     1002 non-null   object
# dtypes: float64(4), int64(1), object(14)
# memory usage: 148.9+ KB

# %%
dfvpp_cpy.shape
# Out:
# (1002, 19)

# %%
Null_val={'description':56,
'price':23,
'engine':2,
'cylinders':105,
'fuel':7,
'mileage':34,
'transmission':2,
'trim':1,
'body':3,
'doors':7,
'exterior_color':5,
'interior_color':38}

# %%
icdict=dict(dfvpp_cpy['interior_color'].value_counts())
icdict
# Out:
# {'Black': np.int64(510),
#  'Global Black': np.int64(84),
#  'Gray': np.int64(77),
#  'Jet Black': np.int64(45),
#  'Ebony': np.int64(43),
#  'Charcoal': np.int64(29),
#  'Black Onyx': np.int64(16),
#  'Titan Black': np.int64(11),
#  'Diesel Gray/Black': np.int64(6),
#  'Graphite': np.int64(6),
#  'Black Interior Color': np.int64(6),
#  'Greige': np.int64(6),
#  'Medium Ash Gray': np.int64(5),
#  'Beige / Black': np.int64(5),
#  'Medium Gray': np.int64(5),
#  'Dark Gray': np.int64(4),
#  'Pebble Gray': np.int64(3),
#  'Beige': np.int64(3),
#  'White': np.int64(3),
#  'Dk Palazzo Gry Fron': np.int64(3),
#  'Okapi Brown': np.int64(3),
#  'Ruby Red/Black': np.int64(3),
#  'Red': np.int64(3),
#  'Tacora Red': np.int64(3),
#  'Jet Blk': np.int64(2),
#  'Cognac': np.int64(2),
#  'Teak/Light Shale': np.int64(2),
#  'Noir w/Santorini Blue Accents': np.int64(2),
#  'Nh-731p/Black': np.int64(2),
#  'Tupelo': np.int64(2),
#  'Pearl Beige': np.int64(2),
#  'Jet Blk Premium Clth': np.int64(2),
#  'Dark Palazzo Gray': np.int64(2),
#  'Macchiato Beige': np.int64(2),
#  'Griege': np.int64(2),
#  'Black w/Red Accents': np.int64(2),
#  'Alpine Umber': np.int64(2),
#  'Wicker Beige/Black': np.int64(2),
#  'Black / Diesel Gray': np.int64(2),
#  'Medium Earth Gray': np.int64(1),
#  'Steel Gry Premium Cl': np.int64(1),
#  'Black Cloud': np.int64(1),
#  'Ruby Red': np.int64(1),
#  'Sepia / Black': np.int64(1),
#  'Gry Lthette': np.int64(1),
#  'Jet Black With Red Accents': np.int64(1),
#  'Lt Mountain Brown/Brown': np.int64(1),
#  'Gideon/Very Dark Atmosphere': np.int64(1),
#  'Dark Walnut / Slate': np.int64(1),
#  'Nutmeg': np.int64(1),
#  'Medium Pewter': np.int64(1),
#  'Ebony W/Red Stitching': np.int64(1),
#  'Black/Alloy/Black': np.int64(1),
#  'Sea Salt': np.int64(1),
#  'Medium Sandstone': np.int64(1),
#  'Ebony/Roast': np.int64(1),
#  'Mauro Brown': np.int64(1),
#  'Ebony Black': np.int64(1),
#  'Jet Black w/Red Accents': np.int64(1),
#  'Oyster': np.int64(1),
#  'Dark Green': np.int64(1),
#  'Brown/Blk': np.int64(1),
#  'Gray / Black': np.int64(1),
#  'Black SofTex-trimmed\xa0[softex]': np.int64(1),
#  'Ash': np.int64(1),
#  'Volcano Brown': np.int64(1),
#  'Tupelo/Black': np.int64(1),
#  'Light Platinum': np.int64(1),
#  'Bk': np.int64(1),
#  'Sandstone': np.int64(1),
#  'Diesel Gray / Black': np.int64(1),
#  'Mojave Dusk/Onyx': np.int64(1),
#  'Monaco Red': np.int64(1),
#  'Tan': np.int64(1),
#  'Melange': np.int64(1),
#  'Medium Soft Ceramic': np.int64(1),
#  'Dark Galvanized': np.int64(1),
#  'Boulder': np.int64(1),
#  'Space Gray': np.int64(1),
#  'Dune': np.int64(1),
#  'Wicker Beige/Global Black': np.int64(1),
#  'Espresso': np.int64(1),
#  'Nh-797m/Black': np.int64(1),
#  'Dk Palazzo Gry Clth Front': np.int64(1),
#  'Silverstone': np.int64(1),
#  'Java': np.int64(1),
#  'Caramel': np.int64(1),
#  'gray': np.int64(1),
#  'Dark Palazzo': np.int64(1),
#  'Gray/Black': np.int64(1),
#  'Navy Pier': np.int64(1)}

# %%
dfvpp_cpy.describe(include='object')
# Out:
#                               name                        description  make  \
# count                         1002                                946  1002
# unique                         358                                761    28
# top     2023 Dodge Durango Pursuit  \n      \n        .\n      \n      Jeep
# freq                            33                                 13   194
#
#          model              engine      fuel       transmission     trim body  \
# count     1002                1000       995               1000     1001  999
# unique     153                 100         7                 38      197    8
# top     Hornet  16V GDI DOHC Turbo  Gasoline  8-Speed Automatic  Limited  SUV
# freq        65                 130       664                325       69  704
#
#                 exterior_color interior_color       drivetrain first_4_char  \
# count                      997            964             1002         1002
# unique                     263             91                4            3
# top     Bright White Clearcoat          Black  All-wheel Drive         2024
# freq                        81            510              461          906
#
#                    remain_char
# count                     1002
# unique                     337
# top      Dodge Durango Pursuit
# freq                        35

# %% [markdown]
# ###Convert Object to String Data Type

# %%
dfvpp_cpy['name']=dfvpp_cpy['name'].astype("string")

# %%
dfvpp_cpy['description']=dfvpp_cpy['description'].astype("string")

# %%
dfvpp_cpy['make']=dfvpp_cpy['make'].astype("string")

# %%
dfvpp_cpy['model']=dfvpp_cpy['model'].astype("string")

# %%
dfvpp_cpy['engine']=dfvpp_cpy['engine'].astype("string")

# %%
dfvpp_cpy['fuel']=dfvpp_cpy['fuel'].astype("string")

# %%
dfvpp_cpy['transmission']=dfvpp_cpy['transmission'].astype("string")

# %%
dfvpp_cpy['trim']=dfvpp_cpy['trim'].astype("string")

# %%
dfvpp_cpy['exterior_color']=dfvpp_cpy['exterior_color'].astype("string")

# %%
dfvpp_cpy['interior_color']=dfvpp_cpy['interior_color'].astype("string")

# %% [markdown]
# ###Filling Missing Values

# %%
dfvpp_cpy['description'].fillna(dfvpp_cpy['description'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2394251440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['description'].fillna(dfvpp_cpy['description'].mode()[0], inplace=True)

# %%
dfvpp_cpy['price'].fillna(dfvpp_cpy['price'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-83493644.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['price'].fillna(dfvpp_cpy['price'].mean(), inplace=True)

# %%
dfvpp_cpy['engine'].fillna(dfvpp_cpy['engine'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3150972399.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['engine'].fillna(dfvpp_cpy['engine'].mode()[0], inplace=True)

# %%
dfvpp_cpy['cylinders'].fillna(dfvpp_cpy['cylinders'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-777596422.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['cylinders'].fillna(dfvpp_cpy['cylinders'].mean(), inplace=True)

# %%
dfvpp_cpy['fuel'].fillna(dfvpp_cpy['fuel'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3144416185.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['fuel'].fillna(dfvpp_cpy['fuel'].mode()[0], inplace=True)

# %%
dfvpp_cpy['mileage'].fillna(dfvpp_cpy['mileage'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-2069995987.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['mileage'].fillna(dfvpp_cpy['mileage'].mean(), inplace=True)

# %%
dfvpp_cpy['transmission'].fillna(dfvpp_cpy['transmission'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-4129036530.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['transmission'].fillna(dfvpp_cpy['transmission'].mode()[0], inplace=True)

# %%
dfvpp_cpy['trim'].fillna(dfvpp_cpy['trim'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-652711230.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['trim'].fillna(dfvpp_cpy['trim'].mode()[0], inplace=True)

# %%
dfvpp_cpy['body'].fillna(dfvpp_cpy['body'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-875517492.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['body'].fillna(dfvpp_cpy['body'].mode()[0], inplace=True)

# %%
dfvpp_cpy['doors'].fillna(dfvpp_cpy['doors'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3163763116.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['doors'].fillna(dfvpp_cpy['doors'].mean(), inplace=True)

# %%
dfvpp_cpy['exterior_color'].fillna(dfvpp_cpy['exterior_color'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1698544598.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['exterior_color'].fillna(dfvpp_cpy['exterior_color'].mode()[0], inplace=True)

# %%
dfvpp_cpy['interior_color'].fillna(dfvpp_cpy['interior_color'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1291575588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfvpp_cpy['interior_color'].fillna(dfvpp_cpy['interior_color'].mode()[0], inplace=True)

# %%
dfvpp_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   string
#  1   description     1002 non-null   string
#  2   make            1002 non-null   string
#  3   model           1002 non-null   string
#  4   year            1002 non-null   int64
#  5   price           1002 non-null   float64
#  6   engine          1002 non-null   string
#  7   cylinders       1002 non-null   float64
#  8   fuel            1002 non-null   string
#  9   mileage         1002 non-null   float64
#  10  transmission    1002 non-null   string
#  11  trim            1002 non-null   string
#  12  body            1002 non-null   object
#  13  doors           1002 non-null   float64
#  14  exterior_color  1002 non-null   string
#  15  interior_color  1002 non-null   string
#  16  drivetrain      1002 non-null   object
#  17  first_4_char    1002 non-null   object
#  18  remain_char     1002 non-null   object
# dtypes: float64(4), int64(1), object(4), string(10)
# memory usage: 148.9+ KB

# %%
dfvpp_cpy.drop(['first_4_char','remain_char'], axis=1,inplace=True)

# %%
dfvpp_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   string
#  1   description     1002 non-null   string
#  2   make            1002 non-null   string
#  3   model           1002 non-null   string
#  4   year            1002 non-null   int64
#  5   price           1002 non-null   float64
#  6   engine          1002 non-null   string
#  7   cylinders       1002 non-null   float64
#  8   fuel            1002 non-null   string
#  9   mileage         1002 non-null   float64
#  10  transmission    1002 non-null   string
#  11  trim            1002 non-null   string
#  12  body            1002 non-null   object
#  13  doors           1002 non-null   float64
#  14  exterior_color  1002 non-null   string
#  15  interior_color  1002 non-null   string
#  16  drivetrain      1002 non-null   object
# dtypes: float64(4), int64(1), object(2), string(10)
# memory usage: 133.2+ KB

# %% [markdown]
# ###Extracting Text Features

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df_name = TfidfVectorizer(max_features=2000)
dfname = df_name.fit_transform(dfvpp_cpy['name'])

# %%
df_desc = TfidfVectorizer(max_features=2000)
dfdesc = df_desc.fit_transform(dfvpp_cpy['description'])

# %%
df_make = TfidfVectorizer(max_features=2000)
dfmake = df_make.fit_transform(dfvpp_cpy['make'])

# %%
df_model = TfidfVectorizer(max_features=2000)
dfmodel = df_model.fit_transform(dfvpp_cpy['model'])

# %%
df_engine = TfidfVectorizer(max_features=2000)
dfengine = df_engine.fit_transform(dfvpp_cpy['engine'])

# %%
df_fuel = TfidfVectorizer(max_features=2000)
dffuel = df_fuel.fit_transform(dfvpp_cpy['fuel'])

# %%
df_trans = TfidfVectorizer(max_features=2000)
dftrans = df_trans.fit_transform(dfvpp_cpy['transmission'])

# %%
df_trim = TfidfVectorizer(max_features=2000)
dftrim = df_trim.fit_transform(dfvpp_cpy['trim'])

# %%
df_body = TfidfVectorizer(max_features=2000)
dfbody = df_body.fit_transform(dfvpp_cpy['body'])

# %%
df_ecolor = TfidfVectorizer(max_features=2000)
dfecolor = df_ecolor.fit_transform(dfvpp_cpy['exterior_color'])

# %%
df_icolor = TfidfVectorizer(max_features=2000)
dficolor = df_icolor.fit_transform(dfvpp_cpy['interior_color'])

# %%
df_dtrain = TfidfVectorizer(max_features=2000)
dfdtrain = df_dtrain.fit_transform(dfvpp_cpy['drivetrain'])

# %%
dfdesc
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 85835 stored elements and shape (1002, 2000)>

# %%
txt_cols=[dfname, dfdesc, dfmake, dfmodel, dfengine, dffuel, dftrans, dftrim, dfbody, dficolor, dficolor, dfdtrain]

# %% [markdown]
# ###Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

Num_cols=['year','cylinders','mileage','doors']
SS=StandardScaler()

Num_Features=SS.fit_transform(dfvpp_cpy[Num_cols])
dfvpp_cpy['price']=SS.fit_transform(dfvpp_cpy[['price']])

# %% [markdown]
# ###Stacking

# %%
from scipy.sparse import hstack, csr_matrix

NumFeat=csr_matrix(Num_Features)
new_df=hstack([NumFeat, dfname, dfdesc, dfmake, dfmodel, dfengine, dffuel, dftrans, dftrim, dfbody, dficolor, dficolor, dfdtrain])

# %%
new_df
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 112493 stored elements and shape (1002, 3077)>

# %% [markdown]
# ###Seperating the Independent & Dependent Features

# %%
X=new_df
y=dfvpp_cpy['price']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (801, 3077)
# (201, 3077)
# (801,)
# (201,)

# %% [markdown]
# ###Model Building

# %% [markdown]
# ####Model 1: Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model=LinearRegression()

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_train, y_train)
# Out:
# 0.9992874434854593

# %%
lr_model.fit(X_test, y_test)
# Out:
# LinearRegression()

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.9996586629108828

# %% [markdown]
# ####Model Predictions on test dataset

# %%
mod1_pred=lr_model.predict(X_test)

# %%
new_df[:1,0:3077]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 178 stored elements and shape (1, 3077)>

# %%
pred1=lr_model.predict(new_df[:1,0:3077])
print(pred1)
ov=SS.inverse_transform([pred1])
print(ov[0][0])
ov
# Out:
# [0.86293035]
# 66145.69121495624
# array([[66145.69121496]])

# %%
from sklearn.metrics import r2_score, mean_squared_error

R2= r2_score(y_test, mod1_pred)
print(f'The R² value-Coeff of Determination is found to be::{R2}')
print()
MSE=mean_squared_error(mod1_pred, y_test)
print(f'The Mean Square Error value-MSE is found to be::{MSE}')
# Out:
# The R² value-Coeff of Determination is found to be::0.9996586629108828
#
# The Mean Square Error value-MSE is found to be::0.0002549417465860021
